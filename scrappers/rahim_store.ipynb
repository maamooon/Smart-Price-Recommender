# %%
import asyncio
from playwright.async_api import async_playwright
import csv
import os
from typing import List, Dict, Optional
import logging
from datetime import datetime
import time
import sys

# Set up detailed logging with real-time output
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s | %(levelname)-8s | %(message)s',
    datefmt='%H:%M:%S',
    handlers=[
        logging.FileHandler('rahim_scraper_detailed.log', encoding='utf-8'),
        logging.StreamHandler(sys.stdout)
    ]
)
logger = logging.getLogger(__name__)

class RahimStoreScraper:
    def __init__(self):
        self.base_url = "https://www.rahimstore.com/department/"
        self.departments = ['001', '002', '003', '004', '005', '006']
        self.output_file = f'rahim_store_products_{datetime.now().strftime("%Y%m%d_%H%M%S")}.csv'
        self.product_data = []
        self.stats = {
            'total_products': 0,
            'failed_products': 0,
            'department_stats': {},
            'start_time': None,
            'end_time': None,
            'current_department': None,
            'current_page': 0
        }

    def print_banner(self):
        """Print startup banner"""
        print("\n" + "═" * 80)
        print("🎯 RAHIM STORE WEB SCRAPER - REAL-TIME MONITORING")
        print("═" * 80)
        print(f"🕐 Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"💾 Output file: {self.output_file}")
        print(f"🏪 Departments: {', '.join(self.departments)}")
        print("═" * 80)
        print("📡 LIVE LOGS STARTING...")
        print("─" * 80)

    def print_live_status(self, action: str, details: str = ""):
        """Print real-time status updates"""
        timestamp = datetime.now().strftime('%H:%M:%S')
        print(f"[{timestamp}] 🔄 {action}: {details}")

    def print_product_extracted(self, product_name: str, product_id: str, price: str):
        """Print when a product is successfully extracted"""
        timestamp = datetime.now().strftime('%H:%M:%S')
        print(f"[{timestamp}] ✅ EXTRACTED: '{product_name}' (ID: {product_id}) - Price: {price}")

    def print_page_progress(self, dept: str, page: int, current: int, total: int):
        """Print page-by-page progress"""
        progress = f"Dept {dept} | Page {page} | Progress: {current}/{total} products"
        percentage = (current / total) * 100 if total > 0 else 0
        print(f"📊 [{dept}-P{page}] █{'█' * int(percentage/10)}{'░' * (10 - int(percentage/10))}│ {current}/{total} ({percentage:.1f}%)")

    def print_department_summary(self, dept: str, total_products: int, duration: float):
        """Print department completion summary"""
        print("─" * 80)
        print(f"🏁 DEPARTMENT {dept} COMPLETED!")
        print(f"📦 Total products: {total_products}")
        print(f"⏱️  Time taken: {duration:.2f} seconds")
        print("─" * 80)

    def print_final_summary(self):
        """Print final summary"""
        total_duration = self.stats['end_time'] - self.stats['start_time']

        print("\n" + "═" * 80)
        print("🎉 SCRAPING COMPLETED - FINAL SUMMARY")
        print("═" * 80)
        print(f"⏱️  Total duration: {total_duration:.2f} seconds")
        print(f"📊 Total products: {self.stats['total_products']}")
        print(f"❌ Failed extractions: {self.stats['failed_products']}")
        print(f"💾 Output file: {self.output_file}")

        print("\n📈 DEPARTMENT BREAKDOWN:")
        for dept in self.departments:
            count = self.stats['department_stats'].get(dept, 0)
            print(f"   └── Department {dept}: {count} products")

        total_attempts = self.stats['total_products'] + self.stats['failed_products']
        success_rate = (self.stats['total_products'] / total_attempts * 100) if total_attempts > 0 else 0
        print(f"\n📊 Success rate: {success_rate:.1f}%")
        print("═" * 80)

    async def setup_browser(self) -> bool:
        """Initialize browser and context"""
        try:
            self.print_live_status("INITIALIZING BROWSER", "Starting Playwright...")
            self.stats['start_time'] = time.time()

            self.playwright = await async_playwright().start()
            self.browser = await self.playwright.chromium.launch(
                headless=True,
                args=[
                    '--no-sandbox',
                    '--disable-dev-shm-usage',
                    '--disable-blink-features=AutomationControlled',
                    '--disable-features=VizDisplayCompositor'
                ]
            )

            self.context = await self.browser.new_context(
                viewport={'width': 1920, 'height': 1080},
                user_agent='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
                extra_http_headers={
                    'Accept-Language': 'en-US,en;q=0.9',
                    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'
                }
            )

            self.print_live_status("BROWSER READY", "Chromium initialized successfully")
            return True

        except Exception as e:
            self.print_live_status("BROWSER FAILED", f"Error: {str(e)}")
            return False

    async def close_browser(self):
        """Close browser resources"""
        try:
            if hasattr(self, 'context'):
                await self.context.close()
            if hasattr(self, 'browser'):
                await self.browser.close()
            if hasattr(self, 'playwright'):
                await self.playwright.stop()
            self.print_live_status("BROWSER CLOSED", "All resources cleaned up")
        except Exception as e:
            self.print_live_status("CLEANUP ERROR", f"Error: {str(e)}")

    def save_to_csv(self) -> bool:
        """Save data to CSV file"""
        try:
            if not self.product_data:
                self.print_live_status("CSV SAVE", "No data to save")
                return False

            fieldnames = [
                'department_id', 'product_id', 'product_name', 'current_price',
                'original_price', 'product_url', 'image_url', 'was_price',
                'scraped_timestamp'
            ]

            with open(self.output_file, 'w', newline='', encoding='utf-8') as csvfile:
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                writer.writeheader()
                writer.writerows(self.product_data)

            self.print_live_status("CSV SAVED", f"{len(self.product_data)} products saved to {self.output_file}")
            return True

        except Exception as e:
            self.print_live_status("CSV ERROR", f"Failed to save: {str(e)}")
            return False

    async def wait_for_products_fully_loaded(self, page, department_id: str, page_number: int):
        """Wait for products to be fully loaded with multiple verification steps"""
        try:
            self.print_live_status("WAITING", f"Waiting for products to fully load on page {page_number}")

            # Wait for the main product container to be present
            await page.wait_for_selector('.item.img-hover-zoom--quick-zoom', timeout=20000)
            self.print_live_status("LOAD CHECK", "Initial product container found")

            # Wait for additional time to ensure all content is loaded
            await asyncio.sleep(2)

            # Check if product images are loaded
            images_loaded = await page.query_selector_all('img.img-fluid[src]')
            self.print_live_status("LOAD CHECK", f"{len(images_loaded)} product images found")

            # Wait for prices to be loaded
            prices_loaded = await page.query_selector_all('strong')
            self.print_live_status("LOAD CHECK", f"{len(prices_loaded)} price elements found")

            # Final wait to ensure everything is rendered
            await asyncio.sleep(1)

            self.print_live_status("LOAD COMPLETE", "All products fully loaded and ready for scraping")
            return True

        except Exception as e:
            self.print_live_status("LOAD ERROR", f"Failed to wait for products: {str(e)}")
            return False

    async def extract_product_info(self, product_card, department_id: str, card_index: int) -> Optional[Dict]:
        """Extract detailed product information with real-time logging"""
        try:
            # Extract product name
            name_element = await product_card.query_selector('a[style="display:block; height:50px;"]')
            if not name_element:
                self.print_live_status("EXTRACTION FAILED", f"Card {card_index}: No name element found")
                return None

            product_name = await name_element.inner_text()
            product_name = product_name.strip() if product_name else "N/A"

            # Extract product URL and ID
            product_url = await name_element.get_attribute('href') or "N/A"
            product_id = await name_element.get_attribute('productid') or "N/A"

            # Extract image
            img_element = await product_card.query_selector('img.img-fluid')
            image_url = await img_element.get_attribute('src') if img_element else "N/A"

            # Extract prices
            strong_element = await product_card.query_selector('strong')
            current_price = await strong_element.inner_text() if strong_element else "N/A"
            current_price = current_price.replace('Rs', '').replace('sup', '').strip()

            strike_element = await product_card.query_selector('strike')
            was_price = await strike_element.inner_text() if strike_element else "N/A"

            # Get additional price data from button
            button_element = await product_card.query_selector('button.btn-success')
            original_price = was_price

            if button_element:
                button_data = await button_element.get_attribute('data')
                if button_data and '~' in button_data:
                    data_parts = button_data.split('~')
                    if len(data_parts) >= 4:
                        original_price = data_parts[3]

            product_info = {
                'department_id': department_id,
                'product_id': product_id,
                'product_name': product_name,
                'current_price': current_price,
                'original_price': original_price,
                'product_url': product_url,
                'image_url': image_url,
                'was_price': was_price,
                'scraped_timestamp': datetime.now().isoformat()
            }

            # Print successful extraction
            self.print_product_extracted(product_name, product_id, current_price)
            return product_info

        except Exception as e:
            self.print_live_status("EXTRACTION ERROR", f"Card {card_index}: {str(e)}")
            self.stats['failed_products'] += 1
            return None

    async def handle_pagination(self, page, department_id: str, current_page: int) -> bool:
        """Handle pagination to next page with proper waiting"""
        try:
            self.print_live_status("PAGINATION", f"Checking for page {current_page + 1}")

            # Wait for pagination to load
            await page.wait_for_selector('.pagination', timeout=10000)

            # Find next button
            next_button = await page.query_selector('a.page-link[aria-label="Next"]')
            if not next_button:
                self.print_live_status("PAGINATION", "No next button found")
                return False

            # Check if next button is disabled
            is_disabled = await next_button.evaluate('(element) => element.parentElement.classList.contains("disabled")')
            if is_disabled:
                self.print_live_status("PAGINATION", f"Reached last page ({current_page})")
                return False

            # Click next button
            self.print_live_status("PAGINATION", f"Moving to page {current_page + 1}")
            await next_button.click()

            # Wait for navigation to complete and new page to load
            self.print_live_status("WAITING", "Waiting for new page to load after pagination...")
            await page.wait_for_timeout(4000)  # Increased wait time for page transition

            # Wait for products to be fully loaded on the new page
            await self.wait_for_products_fully_loaded(page, department_id, current_page + 1)

            self.print_live_status("PAGINATION", f"Successfully loaded page {current_page + 1}")
            return True

        except Exception as e:
            self.print_live_status("PAGINATION ERROR", f"Page {current_page}: {str(e)}")
            return False

    async def scrape_department_page(self, page, department_id: str, page_number: int) -> bool:
        """Scrape a single page of products with proper loading waits"""
        try:
            self.stats['current_page'] = page_number
            self.print_live_status("PAGE START", f"Department {department_id} - Page {page_number}")

            # Wait for products to be fully loaded before scraping
            if not await self.wait_for_products_fully_loaded(page, department_id, page_number):
                self.print_live_status("PAGE ERROR", f"Products not loaded properly on page {page_number}")
                return False

            # Get all product cards after ensuring they're loaded
            product_cards = await page.query_selector_all('.item.img-hover-zoom--quick-zoom')

            if not product_cards:
                self.print_live_status("PAGE EMPTY", "No product cards found after waiting")
                return False

            self.print_live_status("PRODUCTS FOUND", f"Found {len(product_cards)} products on page {page_number}")

            # Extract each product with small delays between extractions
            successful_extractions = 0
            for i, card in enumerate(product_cards, 1):
                # Show progress every 5 products
                if i % 5 == 0 or i == len(product_cards):
                    self.print_page_progress(department_id, page_number, i, len(product_cards))

                # Small delay between product extractions to be respectful
                if i > 1:
                    await asyncio.sleep(0.1)

                product_info = await self.extract_product_info(card, department_id, i)
                if product_info:
                    self.product_data.append(product_info)
                    successful_extractions += 1
                    self.stats['total_products'] += 1

            self.print_live_status("PAGE COMPLETE",
                f"Page {page_number}: {successful_extractions}/{len(product_cards)} products extracted")

            # Handle pagination
            has_next_page = await self.handle_pagination(page, department_id, page_number)
            return has_next_page

        except Exception as e:
            self.print_live_status("PAGE ERROR", f"Department {department_id} Page {page_number}: {str(e)}")
            return False

    async def scrape_department(self, department_id: str):
        """Scrape all pages of a department with proper loading waits"""
        dept_start_time = time.time()
        url = f"{self.base_url}{department_id}"

        self.stats['current_department'] = department_id
        print(f"\n{'=' * 80}")
        print(f"🚀 STARTING DEPARTMENT {department_id}")
        print(f"🌐 URL: {url}")
        print(f"{'=' * 80}")

        page = await self.context.new_page()
        dept_products_start = len(self.product_data)

        try:
            # Navigate to department with longer timeout
            self.print_live_status("NAVIGATING", f"Loading {url} (waiting for full load)...")
            response = await page.goto(url, wait_until='domcontentloaded', timeout=45000)

            if not response or response.status != 200:
                status_code = getattr(response, 'status', 'Unknown')
                self.print_live_status("NAVIGATION FAILED", f"HTTP {status_code}")
                return

            self.print_live_status("PAGE LOADED", "Initial page loaded, waiting for full content...")

            # Wait for the department page to be fully ready
            await self.wait_for_products_fully_loaded(page, department_id, 1)

            # Scrape all pages
            page_number = 1
            max_pages = 100  # Safety limit

            while page_number <= max_pages:
                has_next_page = await self.scrape_department_page(page, department_id, page_number)

                if not has_next_page:
                    self.print_live_status("DEPARTMENT COMPLETE", f"No more pages after page {page_number}")
                    break

                page_number += 1
                # Increased pause between pages
                await asyncio.sleep(2)

            # Department summary
            dept_products_count = len(self.product_data) - dept_products_start
            self.stats['department_stats'][department_id] = dept_products_count
            dept_duration = time.time() - dept_start_time

            self.print_department_summary(department_id, dept_products_count, dept_duration)

        except Exception as e:
            self.print_live_status("DEPARTMENT ERROR", f"Department {department_id}: {str(e)}")
        finally:
            await page.close()
            self.print_live_status("PAGE CLOSED", f"Department {department_id} browser page closed")

    async def run_scraper(self):
        """Main scraper execution function"""
        self.print_banner()

        if not await self.setup_browser():
            return

        try:
            # Scrape each department
            for i, department_id in enumerate(self.departments, 1):
                print(f"\n📊 OVERALL PROGRESS: Department {i}/{len(self.departments)}")
                await self.scrape_department(department_id)

                # Longer pause between departments to be respectful
                if i < len(self.departments):
                    self.print_live_status("PAUSING", "Waiting 5 seconds before next department...")
                    await asyncio.sleep(5)

            # Final save and summary
            self.stats['end_time'] = time.time()
            self.save_to_csv()
            self.print_final_summary()

        except KeyboardInterrupt:
            self.print_live_status("INTERRUPTED", "User stopped the scraper")
            print("\n💾 Saving collected data before exit...")
            self.save_to_csv()
        except Exception as e:
            self.print_live_status("FATAL ERROR", f"Scraper crashed: {str(e)}")
        finally:
            await self.close_browser()

async def main():
    """Main execution function"""
    print("🚀 Initializing Rahim Store Scraper with Real-time Monitoring...")

    try:
        scraper = RahimStoreScraper()
        await scraper.run_scraper()
    except Exception as e:
        print(f"💥 Fatal initialization error: {e}")

if __name__ == "__main__":
    # Run the scraper
    await main()
# Out:
# Streaming output truncated to the last 5000 lines.
# [18:22:47] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P7] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:22:47] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:22:47] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:22:47] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:22:47] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:22:47] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P7] ████░░░░░░░│ 10/33 (30.3%)
# [18:22:47] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:22:48] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:22:48] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:22:48] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:22:48] ✅ EXTRACTED: 'Monsalwa Seekh Kabab 360gm' (ID: 2410) - Price: 705.00
# 📊 [004-P7] █████░░░░░░│ 15/33 (45.5%)
# [18:22:48] ✅ EXTRACTED: 'Monsalwa Chiken Kofta 600gm' (ID: 2422) - Price: 899.00
# [18:22:48] ✅ EXTRACTED: 'Monsalwa Shami Kabab 576gm' (ID: 2423) - Price: 900.00
# [18:22:49] ✅ EXTRACTED: 'Monsalwa Wheat Paratha 20 Piec' (ID: 2428) - Price: 890.00
# [18:22:49] ✅ EXTRACTED: 'Monsalwa Plain Paratha 5 Piece' (ID: 2430) - Price: 215.00
# [18:22:49] ✅ EXTRACTED: 'Monsalwa Lachchaydar Paratha 5' (ID: 2431) - Price: 180.00
# 📊 [004-P7] ███████░░░░│ 20/33 (60.6%)
# [18:22:49] ✅ EXTRACTED: 'Pk Beef Kofta 500gm' (ID: 2450) - Price: 939.00
# [18:22:49] ✅ EXTRACTED: 'Menu Seekh Kabab 540gm' (ID: 2744) - Price: 1,185.00
# [18:22:50] ✅ EXTRACTED: 'Menu Chapli Kabab 888gm' (ID: 2746) - Price: 1,325.00
# [18:22:50] ✅ EXTRACTED: 'Menu Gola Kabab 660gm' (ID: 2747) - Price: 1,399.00
# [18:22:50] ✅ EXTRACTED: 'Menu Burger Patties 1075gm' (ID: 2749) - Price: 1,450.00
# 📊 [004-P7] ████████░░░│ 25/33 (75.8%)
# [18:22:50] ✅ EXTRACTED: 'Menu Chicken Nuggets 270gm' (ID: 2751) - Price: 560.00
# [18:22:50] ✅ EXTRACTED: 'Menu Chicken Pop Corn 780gm' (ID: 2757) - Price: 1,255.00
# [18:22:51] ✅ EXTRACTED: 'Menu Chicken Kofta 1kg' (ID: 2760) - Price: 1,640.00
# [18:22:51] ✅ EXTRACTED: 'Menu Chicken Nuggets 1kg' (ID: 2762) - Price: 1,355.00
# [18:22:51] ✅ EXTRACTED: 'K&ns Kofta 12 Pieces' (ID: 2764) - Price: 605.00
# 📊 [004-P7] ██████████░│ 30/33 (90.9%)
# [18:22:51] ✅ EXTRACTED: 'K&ns Chicken Tender Pops 260gm' (ID: 2767) - Price: 520.00
# [18:22:52] ✅ EXTRACTED: 'K&ns Chicken Nuggets 270 Gm' (ID: 2769) - Price: 505.00
# [18:22:52] ✅ EXTRACTED: 'Murree Brewerys Lychee Malt Gl' (ID: 2795) - Price: 75.00
# 📊 [004-P7] ███████████│ 33/33 (100.0%)
# [18:22:52] ✅ EXTRACTED: 'Fanta Ornage Drink Tin 250ml' (ID: 2797) - Price: 100.00
# [18:22:52] 🔄 PAGE COMPLETE: Page 7: 20/33 products extracted
# [18:22:52] 🔄 PAGINATION: Checking for page 8
# [18:22:52] 🔄 PAGINATION: Moving to page 8
# [18:22:52] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:22:56] 🔄 WAITING: Waiting for products to fully load on page 8
# [18:22:56] 🔄 LOAD CHECK: Initial product container found
# [18:22:58] 🔄 LOAD CHECK: 20 product images found
# [18:22:58] 🔄 LOAD CHECK: 22 price elements found
# [18:22:59] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:22:59] 🔄 PAGINATION: Successfully loaded page 8
# [18:23:01] 🔄 PAGE START: Department 004 - Page 8
# [18:23:01] 🔄 WAITING: Waiting for products to fully load on page 8
# [18:23:01] 🔄 LOAD CHECK: Initial product container found
# [18:23:03] 🔄 LOAD CHECK: 20 product images found
# [18:23:04] 🔄 LOAD CHECK: 22 price elements found
# [18:23:05] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:23:05] 🔄 PRODUCTS FOUND: Found 33 products on page 8
# [18:23:05] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:23:05] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:23:05] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:23:05] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P8] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:23:06] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:23:06] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:23:06] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:23:06] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:23:06] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P8] ████░░░░░░░│ 10/33 (30.3%)
# [18:23:06] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:23:06] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:23:06] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:23:06] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:23:07] ✅ EXTRACTED: 'Red Bull Energy Drink 250ml' (ID: 2801) - Price: 460.00
# 📊 [004-P8] █████░░░░░░│ 15/33 (45.5%)
# [18:23:07] ✅ EXTRACTED: 'Coca Cola Zero Drink Tin 250ml' (ID: 2803) - Price: 100.00
# [18:23:07] ✅ EXTRACTED: 'Sprite Zero Drink Tin 250ml' (ID: 2805) - Price: 100.00
# [18:23:07] ✅ EXTRACTED: 'Coca Cola Drink Tin 250ml' (ID: 2808) - Price: 100.00
# [18:23:08] ✅ EXTRACTED: 'Fanta Orange 500ml' (ID: 2827) - Price: 90.00
# [18:23:08] ✅ EXTRACTED: 'Fanta Orange 1ltr' (ID: 2829) - Price: 150.00
# 📊 [004-P8] ███████░░░░│ 20/33 (60.6%)
# [18:23:08] ✅ EXTRACTED: 'Sprite 1.5ltr' (ID: 2846) - Price: 180.00
# [18:23:09] ✅ EXTRACTED: 'Sprite 500ml' (ID: 2851) - Price: 90.00
# [18:23:09] ✅ EXTRACTED: 'Coca Cola 500ml' (ID: 2854) - Price: 90.00
# [18:23:09] ✅ EXTRACTED: 'Coca Cola 1ltr' (ID: 2856) - Price: 150.00
# [18:23:09] ✅ EXTRACTED: 'Coca Cola Drink 1.5ltr' (ID: 2860) - Price: 178.00
# 📊 [004-P8] ████████░░░│ 25/33 (75.8%)
# [18:23:10] ✅ EXTRACTED: 'Coca Cola Zero 1.5ltr' (ID: 2865) - Price: 178.00
# [18:23:10] ✅ EXTRACTED: 'Sprite Drink 1ltr' (ID: 2868) - Price: 150.00
# [18:23:10] ✅ EXTRACTED: 'Fanta Drink 1.5ltr' (ID: 2872) - Price: 178.00
# [18:23:10] ✅ EXTRACTED: 'Sprite Zero 500ml' (ID: 2878) - Price: 100.00
# [18:23:11] ✅ EXTRACTED: 'Cappy Pulpy Orange 350ml' (ID: 2882) - Price: 115.00
# 📊 [004-P8] ██████████░│ 30/33 (90.9%)
# [18:23:11] ✅ EXTRACTED: 'Anhaar Plain Yogurt 400gm' (ID: 3252) - Price: 250.00
# [18:23:11] ✅ EXTRACTED: 'Anhaar Sweetened Yogurt 400gm' (ID: 3255) - Price: 250.00
# [18:23:12] ✅ EXTRACTED: 'Anhaar Strawberry Yogurt 80gm' (ID: 3266) - Price: 85.00
# 📊 [004-P8] ███████████│ 33/33 (100.0%)
# [18:23:12] ✅ EXTRACTED: 'Anhaar Greek Style Yogurt 250g' (ID: 3269) - Price: 215.00
# [18:23:12] 🔄 PAGE COMPLETE: Page 8: 20/33 products extracted
# [18:23:12] 🔄 PAGINATION: Checking for page 9
# [18:23:12] 🔄 PAGINATION: Moving to page 9
# [18:23:12] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:23:16] 🔄 WAITING: Waiting for products to fully load on page 9
# [18:23:16] 🔄 LOAD CHECK: Initial product container found
# [18:23:18] 🔄 LOAD CHECK: 20 product images found
# [18:23:18] 🔄 LOAD CHECK: 22 price elements found
# [18:23:19] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:23:19] 🔄 PAGINATION: Successfully loaded page 9
# [18:23:21] 🔄 PAGE START: Department 004 - Page 9
# [18:23:21] 🔄 WAITING: Waiting for products to fully load on page 9
# [18:23:21] 🔄 LOAD CHECK: Initial product container found
# [18:23:23] 🔄 LOAD CHECK: 20 product images found
# [18:23:23] 🔄 LOAD CHECK: 22 price elements found
# [18:23:24] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:23:24] 🔄 PRODUCTS FOUND: Found 33 products on page 9
# [18:23:24] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:23:24] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:23:25] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:23:25] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P9] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:23:25] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:23:25] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:23:25] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:23:25] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:23:25] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P9] ████░░░░░░░│ 10/33 (30.3%)
# [18:23:25] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:23:25] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:23:26] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:23:26] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:23:26] ✅ EXTRACTED: 'Anhaar Mango Yogurt 80gm' (ID: 3272) - Price: 85.00
# 📊 [004-P9] █████░░░░░░│ 15/33 (45.5%)
# [18:23:26] ✅ EXTRACTED: 'Blue Band Margarine Spread 180' (ID: 3276) - Price: 330.00
# [18:23:26] ✅ EXTRACTED: 'Blue Band Margarine Spread 90g' (ID: 3280) - Price: 190.00
# [18:23:27] ✅ EXTRACTED: 'Flora Original Fat Free 500gm' (ID: 3295) - Price: 1,145.00
# [18:23:27] ✅ EXTRACTED: 'Flora Original Fat Free 250g' (ID: 3299) - Price: 650.00
# [18:23:27] ✅ EXTRACTED: 'Amsons Real Cheddar Cheese 453' (ID: 3303) - Price: 1,170.00
# 📊 [004-P9] ███████░░░░│ 20/33 (60.6%)
# [18:23:28] ✅ EXTRACTED: 'Adams Singles Chees Slice 1 Kg' (ID: 3306) - Price: 1,945.00
# [18:23:28] ✅ EXTRACTED: 'Amsons Pizza Cheese 227gm' (ID: 3308) - Price: 670.00
# [18:23:28] ✅ EXTRACTED: 'Amsons Pizza Cheese 453gm' (ID: 3311) - Price: 1,250.00
# [18:23:28] ✅ EXTRACTED: 'Adams Sandwich Cheese 10slices' (ID: 3315) - Price: 615.00
# [18:23:28] ✅ EXTRACTED: 'Adams Cheddar Cheese 400gm' (ID: 3317) - Price: 1,125.00
# 📊 [004-P9] ████████░░░│ 25/33 (75.8%)
# [18:23:29] ✅ EXTRACTED: 'Adams Cottage Cheese 200gm' (ID: 3320) - Price: 520.00
# [18:23:29] ✅ EXTRACTED: 'Adams Light Cheese 10slices 20' (ID: 3324) - Price: 650.00
# [18:23:29] ✅ EXTRACTED: 'Prema Fresh Milk 1ltr' (ID: 3995) - Price: 365.00
# [18:23:29] ✅ EXTRACTED: 'Adams Plain Yogurt 400gm' (ID: 3996) - Price: 240.00
# [18:23:29] ✅ EXTRACTED: 'Adams Yogurt 200gm' (ID: 3997) - Price: 130.00
# 📊 [004-P9] ██████████░│ 30/33 (90.9%)
# [18:23:30] ✅ EXTRACTED: 'Adams Zeera Raita 200gm' (ID: 3998) - Price: 130.00
# [18:23:30] ✅ EXTRACTED: 'Prema Low Fat Yogurt 375gm' (ID: 3999) - Price: 235.00
# [18:23:30] ✅ EXTRACTED: 'Prema Natural Yogurt 375gm' (ID: 4000) - Price: 230.00
# 📊 [004-P9] ███████████│ 33/33 (100.0%)
# [18:23:30] ✅ EXTRACTED: 'Prema Sweet And Creamy Yogurt' (ID: 4001) - Price: 230.00
# [18:23:30] 🔄 PAGE COMPLETE: Page 9: 20/33 products extracted
# [18:23:30] 🔄 PAGINATION: Checking for page 10
# [18:23:30] 🔄 PAGINATION: Moving to page 10
# [18:23:30] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:23:34] 🔄 WAITING: Waiting for products to fully load on page 10
# [18:23:34] 🔄 LOAD CHECK: Initial product container found
# [18:23:36] 🔄 LOAD CHECK: 20 product images found
# [18:23:36] 🔄 LOAD CHECK: 22 price elements found
# [18:23:37] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:23:37] 🔄 PAGINATION: Successfully loaded page 10
# [18:23:39] 🔄 PAGE START: Department 004 - Page 10
# [18:23:39] 🔄 WAITING: Waiting for products to fully load on page 10
# [18:23:39] 🔄 LOAD CHECK: Initial product container found
# [18:23:41] 🔄 LOAD CHECK: 20 product images found
# [18:23:41] 🔄 LOAD CHECK: 22 price elements found
# [18:23:42] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:23:43] 🔄 PRODUCTS FOUND: Found 33 products on page 10
# [18:23:43] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:23:43] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:23:43] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:23:43] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P10] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:23:43] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:23:43] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:23:43] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:23:43] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:23:43] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P10] ████░░░░░░░│ 10/33 (30.3%)
# [18:23:44] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:23:44] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:23:44] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:23:44] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:23:44] ✅ EXTRACTED: 'Prema Chunky Strawberry Yogurt' (ID: 4002) - Price: 115.00
# 📊 [004-P10] █████░░░░░░│ 15/33 (45.5%)
# [18:23:44] ✅ EXTRACTED: 'Prema Straberry Yogurt 80gm' (ID: 4003) - Price: 100.00
# [18:23:44] ✅ EXTRACTED: 'Adams Podina Raita 200gm' (ID: 4005) - Price: 130.00
# [18:23:45] ✅ EXTRACTED: 'Prema Fresh Milk Butter 190gm' (ID: 4008) - Price: 630.00
# [18:23:45] ✅ EXTRACTED: 'Prema Chocolate Milk 180ml' (ID: 4011) - Price: 130.00
# [18:23:45] ✅ EXTRACTED: 'Prema Blueberry Yogurt 90gm' (ID: 4012) - Price: 115.00
# 📊 [004-P10] ███████░░░░│ 20/33 (60.6%)
# [18:23:45] ✅ EXTRACTED: 'Anhaar Low Fat Milk 1ltr' (ID: 4013) - Price: 345.00
# [18:23:45] ✅ EXTRACTED: 'Anhaar Full Cream Milk 1ltr' (ID: 4014) - Price: 345.00
# [18:23:46] ✅ EXTRACTED: 'Farm Pure Cow Milk 1ltr' (ID: 4017) - Price: 255.00
# [18:23:46] ✅ EXTRACTED: 'Daily Dairy Fresh Milk 1ltr' (ID: 4021) - Price: 240.00
# [18:23:46] ✅ EXTRACTED: 'Anhaar Plain Yogurt 450gm' (ID: 4027) - Price: 195.00
# 📊 [004-P10] ████████░░░│ 25/33 (75.8%)
# [18:23:46] ✅ EXTRACTED: 'Life Style Shan Mashriq Sharba' (ID: 4461) - Price: 299.00
# [18:23:46] ✅ EXTRACTED: '.life Style Sharbat Anar 800ml' (ID: 4465) - Price: 595.00
# [18:23:47] ✅ EXTRACTED: 'Life Style Almond Syrup 800ml' (ID: 4468) - Price: 595.00
# [18:23:47] ✅ EXTRACTED: 'Life Style Sharbat Elachi 800m' (ID: 4469) - Price: 495.00
# [18:23:47] ✅ EXTRACTED: 'Life Style Sharbat Sandal 800m' (ID: 4478) - Price: 495.00
# 📊 [004-P10] ██████████░│ 30/33 (90.9%)
# [18:23:47] ✅ EXTRACTED: 'Life Style Badam Sardai 800ml' (ID: 4494) - Price: 595.00
# [18:23:48] ✅ EXTRACTED: 'Dawn Plain Bread Large' (ID: 4677) - Price: 199.00
# [18:23:48] ✅ EXTRACTED: 'Dawn Plain Bread Small' (ID: 4689) - Price: 110.00
# 📊 [004-P10] ███████████│ 33/33 (100.0%)
# [18:23:48] ✅ EXTRACTED: 'Dawn Crispy Rusk Small 190gm' (ID: 4767) - Price: 140.00
# [18:23:48] 🔄 PAGE COMPLETE: Page 10: 20/33 products extracted
# [18:23:48] 🔄 PAGINATION: Checking for page 11
# [18:23:48] 🔄 PAGINATION: Moving to page 11
# [18:23:48] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:23:52] 🔄 WAITING: Waiting for products to fully load on page 11
# [18:23:52] 🔄 LOAD CHECK: Initial product container found
# [18:23:54] 🔄 LOAD CHECK: 20 product images found
# [18:23:54] 🔄 LOAD CHECK: 22 price elements found
# [18:23:55] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:23:55] 🔄 PAGINATION: Successfully loaded page 11
# [18:23:57] 🔄 PAGE START: Department 004 - Page 11
# [18:23:57] 🔄 WAITING: Waiting for products to fully load on page 11
# [18:23:57] 🔄 LOAD CHECK: Initial product container found
# [18:23:59] 🔄 LOAD CHECK: 20 product images found
# [18:23:59] 🔄 LOAD CHECK: 22 price elements found
# [18:24:00] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:24:00] 🔄 PRODUCTS FOUND: Found 33 products on page 11
# [18:24:00] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:24:00] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:24:00] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:24:01] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P11] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:24:01] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:24:01] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:24:01] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:24:01] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:24:01] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P11] ████░░░░░░░│ 10/33 (30.3%)
# [18:24:01] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:24:01] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:24:01] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:24:02] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:24:02] ✅ EXTRACTED: 'Dawn Crispy Rusk Large 400gm' (ID: 4769) - Price: 230.00
# 📊 [004-P11] █████░░░░░░│ 15/33 (45.5%)
# [18:24:02] ✅ EXTRACTED: 'Dawn Fruit Cake 200gm' (ID: 4771) - Price: 190.00
# [18:24:02] ✅ EXTRACTED: 'Dawn Strawberry Cup Cake 35gm' (ID: 4772) - Price: 30.00
# [18:24:02] ✅ EXTRACTED: 'Dawn Pineapple Cup Cake 35gm' (ID: 4774) - Price: 30.00
# [18:24:03] ✅ EXTRACTED: 'Dawn Bread Crumbs 200gm' (ID: 4775) - Price: 140.00
# [18:24:03] ✅ EXTRACTED: 'Dawn Shawarma Bread 4pcs 270gm' (ID: 4780) - Price: 95.00
# 📊 [004-P11] ███████░░░░│ 20/33 (60.6%)
# [18:24:03] ✅ EXTRACTED: 'Dawn Bran Rusk Small 190gm' (ID: 4781) - Price: 155.00
# [18:24:03] ✅ EXTRACTED: 'Dawn Zeera Rusk Small 190gm' (ID: 4783) - Price: 155.00
# [18:24:03] ✅ EXTRACTED: 'Bread & Beyond Milky Bread Lar' (ID: 4790) - Price: 220.00
# [18:24:04] ✅ EXTRACTED: 'Bread & Beyond Multi Grain Bre' (ID: 4794) - Price: 280.00
# [18:24:04] ✅ EXTRACTED: 'Bread & Beyond Bran Bread Smal' (ID: 4797) - Price: 210.00
# 📊 [004-P11] ████████░░░│ 25/33 (75.8%)
# [18:24:04] ✅ EXTRACTED: 'Bread&beyound Milky Bread Smal' (ID: 4800) - Price: 120.00
# [18:24:04] ✅ EXTRACTED: 'Bread & Beyond Pitta Bread 270' (ID: 4803) - Price: 100.00
# [18:24:04] ✅ EXTRACTED: 'Bread & Beyond Vanilla Muffin' (ID: 4811) - Price: 40.00
# [18:24:05] ✅ EXTRACTED: 'Bread & Beyond Cake Rusk 270gm' (ID: 4815) - Price: 340.00
# [18:24:05] ✅ EXTRACTED: 'Bunnys Sheer Mal 120gm' (ID: 4820) - Price: 65.00
# 📊 [004-P11] ██████████░│ 30/33 (90.9%)
# [18:24:05] ✅ EXTRACTED: 'Bunnys Fruit Bun 85gm' (ID: 4828) - Price: 50.00
# [18:24:05] ✅ EXTRACTED: 'Bunnys Soft Plain Bread Small' (ID: 4832) - Price: 110.00
# [18:24:05] ✅ EXTRACTED: 'Bunnys Soft Plain Bread Large' (ID: 4834) - Price: 200.00
# 📊 [004-P11] ███████████│ 33/33 (100.0%)
# [18:24:06] ✅ EXTRACTED: 'Bunnys Soft Milky Bread Small' (ID: 4837) - Price: 110.00
# [18:24:06] 🔄 PAGE COMPLETE: Page 11: 20/33 products extracted
# [18:24:06] 🔄 PAGINATION: Checking for page 12
# [18:24:06] 🔄 PAGINATION: Moving to page 12
# [18:24:06] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:24:10] 🔄 WAITING: Waiting for products to fully load on page 12
# [18:24:10] 🔄 LOAD CHECK: Initial product container found
# [18:24:12] 🔄 LOAD CHECK: 20 product images found
# [18:24:12] 🔄 LOAD CHECK: 22 price elements found
# [18:24:13] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:24:13] 🔄 PAGINATION: Successfully loaded page 12
# [18:24:15] 🔄 PAGE START: Department 004 - Page 12
# [18:24:15] 🔄 WAITING: Waiting for products to fully load on page 12
# [18:24:15] 🔄 LOAD CHECK: Initial product container found
# [18:24:17] 🔄 LOAD CHECK: 20 product images found
# [18:24:17] 🔄 LOAD CHECK: 22 price elements found
# [18:24:18] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:24:18] 🔄 PRODUCTS FOUND: Found 33 products on page 12
# [18:24:18] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:24:18] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:24:18] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:24:18] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P12] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:24:18] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:24:18] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:24:19] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:24:19] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:24:19] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P12] ████░░░░░░░│ 10/33 (30.3%)
# [18:24:19] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:24:19] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:24:19] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:24:19] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:24:19] ✅ EXTRACTED: 'Bunnys Soft Sandwich Bread' (ID: 4840) - Price: 280.00
# 📊 [004-P12] █████░░░░░░│ 15/33 (45.5%)
# [18:24:20] ✅ EXTRACTED: 'Bunnys Bread Crumbs 500gm' (ID: 4843) - Price: 250.00
# [18:24:20] ✅ EXTRACTED: 'Bunnys Plain Cake Small' (ID: 4849) - Price: 110.00
# [18:24:20] ✅ EXTRACTED: 'Bunnys Fruit Cake 100gm' (ID: 4850) - Price: 110.00
# [18:24:20] ✅ EXTRACTED: 'Bunnys Fruit Cake 175gm' (ID: 4853) - Price: 210.00
# [18:24:20] ✅ EXTRACTED: 'Bunnys Plain Cake 175gm' (ID: 4855) - Price: 190.00
# 📊 [004-P12] ███████░░░░│ 20/33 (60.6%)
# [18:24:21] ✅ EXTRACTED: 'Bunnys Queen Cake 35gm' (ID: 4864) - Price: 35.00
# [18:24:21] ✅ EXTRACTED: 'Bunnys Bran Rusk Small 200gm' (ID: 4865) - Price: 140.00
# [18:24:21] ✅ EXTRACTED: 'Bunnys Plain Rusk Small 190gm' (ID: 4868) - Price: 140.00
# [18:24:21] ✅ EXTRACTED: 'Bunnys Plain Rusk Small 200gm' (ID: 4870) - Price: 140.00
# [18:24:21] ✅ EXTRACTED: 'Bunnys Plain Rusk Large 400gm' (ID: 4872) - Price: 230.00
# 📊 [004-P12] ████████░░░│ 25/33 (75.8%)
# [18:24:22] ✅ EXTRACTED: 'Dawn Plain Paratha 30pcs' (ID: 4941) - Price: 1,280.00
# [18:24:22] ✅ EXTRACTED: 'Dawn Plain Paratha Value Pack' (ID: 4942) - Price: 890.00
# [18:24:22] ✅ EXTRACTED: 'Dawn Paratha 5 Pieces' (ID: 4943) - Price: 230.00
# [18:24:22] ✅ EXTRACTED: 'Dawn Chicken Paratha 3pcs' (ID: 4952) - Price: 430.00
# [18:24:22] ✅ EXTRACTED: 'Sufi Chicken Nuggets 1000gm' (ID: 5476) - Price: 1,360.00
# 📊 [004-P12] ██████████░│ 30/33 (90.9%)
# [18:24:23] ✅ EXTRACTED: 'Sufi Chicken Tenders 675gm' (ID: 5479) - Price: 1,300.00
# [18:24:23] ✅ EXTRACTED: 'Sufi Gola Kabab 515gm' (ID: 5509) - Price: 1,190.00
# [18:24:23] ✅ EXTRACTED: 'Shezan Lemon Squash 1.4ltr' (ID: 5932) - Price: 675.00
# 📊 [004-P12] ███████████│ 33/33 (100.0%)
# [18:24:23] ✅ EXTRACTED: 'Opa Original Fries 900gm' (ID: 5953) - Price: 920.00
# [18:24:23] 🔄 PAGE COMPLETE: Page 12: 20/33 products extracted
# [18:24:23] 🔄 PAGINATION: Checking for page 13
# [18:24:23] 🔄 PAGINATION: Moving to page 13
# [18:24:23] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:24:27] 🔄 WAITING: Waiting for products to fully load on page 13
# [18:24:27] 🔄 LOAD CHECK: Initial product container found
# [18:24:29] 🔄 LOAD CHECK: 20 product images found
# [18:24:30] 🔄 LOAD CHECK: 22 price elements found
# [18:24:31] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:24:31] 🔄 PAGINATION: Successfully loaded page 13
# [18:24:33] 🔄 PAGE START: Department 004 - Page 13
# [18:24:33] 🔄 WAITING: Waiting for products to fully load on page 13
# [18:24:33] 🔄 LOAD CHECK: Initial product container found
# [18:24:35] 🔄 LOAD CHECK: 20 product images found
# [18:24:35] 🔄 LOAD CHECK: 22 price elements found
# [18:24:36] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:24:36] 🔄 PRODUCTS FOUND: Found 33 products on page 13
# [18:24:36] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:24:36] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:24:36] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:24:36] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P13] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:24:36] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:24:36] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:24:36] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:24:36] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:24:37] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P13] ████░░░░░░░│ 10/33 (30.3%)
# [18:24:37] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:24:37] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:24:37] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:24:37] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:24:37] ✅ EXTRACTED: 'Shezan Mix Fruit Juice 1ltr' (ID: 6105) - Price: 225.00
# 📊 [004-P13] █████░░░░░░│ 15/33 (45.5%)
# [18:24:37] ✅ EXTRACTED: 'Nestle F/v Royal Mango Juice 1' (ID: 6118) - Price: 415.00
# [18:24:38] ✅ EXTRACTED: 'Nestle F/v Kinnow Nectar 200ml' (ID: 6176) - Price: 70.00
# [18:24:38] ✅ EXTRACTED: 'Nestle F/v Guava Nectar 200ml' (ID: 6184) - Price: 70.00
# [18:24:38] ✅ EXTRACTED: 'Nestle Nesfruta Apple Juice 2' (ID: 6208) - Price: 50.00
# [18:24:38] ✅ EXTRACTED: 'Nestle Nesfruta Mango Juice 20' (ID: 6210) - Price: 50.00
# 📊 [004-P13] ███████░░░░│ 20/33 (60.6%)
# [18:24:39] ✅ EXTRACTED: 'Nestle F/v Chaunsa Nectar 200' (ID: 6211) - Price: 70.00
# [18:24:39] ✅ EXTRACTED: 'Haleeb Chaunsa Chaunsa Juice' (ID: 6216) - Price: 45.00
# [18:24:39] ✅ EXTRACTED: 'Haleeb Apple Apple Juice 200ml' (ID: 6218) - Price: 50.00
# [18:24:39] ✅ EXTRACTED: 'Refresh Apple Juice 200ml' (ID: 6221) - Price: 50.00
# [18:24:40] ✅ EXTRACTED: 'Refresh Mango Juice 200ml' (ID: 6226) - Price: 50.00
# 📊 [004-P13] ████████░░░│ 25/33 (75.8%)
# [18:24:40] ✅ EXTRACTED: 'Fauji Choco Rings 250gm' (ID: 6262) - Price: 735.00
# [18:24:40] ✅ EXTRACTED: 'Fauji Wheat Flakes 250gm' (ID: 6265) - Price: 695.00
# [18:24:40] ✅ EXTRACTED: 'Fauji Rice Flakes 250gm' (ID: 6267) - Price: 736.00
# [18:24:41] ✅ EXTRACTED: 'Fauji Bran Flakes 300gm' (ID: 6269) - Price: 775.00
# [18:24:41] ✅ EXTRACTED: 'Funchies Mingalz Choco Balls 1' (ID: 6282) - Price: 335.00
# 📊 [004-P13] ██████████░│ 30/33 (90.9%)
# [18:24:41] ✅ EXTRACTED: 'Funchies Mingalz Choco Crunch' (ID: 6381) - Price: 399.00
# [18:24:41] ✅ EXTRACTED: 'Fauji Frosted Flakes 250gm' (ID: 6385) - Price: 720.00
# [18:24:42] ✅ EXTRACTED: 'Fauji New Frootooz 250gm' (ID: 6390) - Price: 775.00
# 📊 [004-P13] ███████████│ 33/33 (100.0%)
# [18:24:42] ✅ EXTRACTED: 'Natures Own White Oats 500gm' (ID: 6404) - Price: 469.00
# [18:24:42] 🔄 PAGE COMPLETE: Page 13: 20/33 products extracted
# [18:24:42] 🔄 PAGINATION: Checking for page 14
# [18:24:42] 🔄 PAGINATION: Moving to page 14
# [18:24:42] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:24:46] 🔄 WAITING: Waiting for products to fully load on page 14
# [18:24:46] 🔄 LOAD CHECK: Initial product container found
# [18:24:48] 🔄 LOAD CHECK: 20 product images found
# [18:24:48] 🔄 LOAD CHECK: 22 price elements found
# [18:24:49] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:24:49] 🔄 PAGINATION: Successfully loaded page 14
# [18:24:51] 🔄 PAGE START: Department 004 - Page 14
# [18:24:51] 🔄 WAITING: Waiting for products to fully load on page 14
# [18:24:51] 🔄 LOAD CHECK: Initial product container found
# [18:24:53] 🔄 LOAD CHECK: 20 product images found
# [18:24:53] 🔄 LOAD CHECK: 22 price elements found
# [18:24:54] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:24:54] 🔄 PRODUCTS FOUND: Found 33 products on page 14
# [18:24:54] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:24:54] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:24:55] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:24:55] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P14] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:24:55] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:24:55] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:24:55] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:24:55] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:24:55] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P14] ████░░░░░░░│ 10/33 (30.3%)
# [18:24:55] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:24:55] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:24:56] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:24:56] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:24:56] ✅ EXTRACTED: 'Natures Own White Oats 200gm' (ID: 6409) - Price: 199.00
# 📊 [004-P14] █████░░░░░░│ 15/33 (45.5%)
# [18:24:56] ✅ EXTRACTED: 'Nestle Nesquik Banana Milk 300' (ID: 6499) - Price: 1,080.00
# [18:24:57] ✅ EXTRACTED: 'Saira Vegetable & Aloo Samosa' (ID: 6541) - Price: 250.00
# [18:24:57] ✅ EXTRACTED: 'Saira Chicken Samosa 260gm' (ID: 6542) - Price: 340.00
# [18:24:57] ✅ EXTRACTED: 'K&ns Seekh Kabab 205gm' (ID: 7010) - Price: 525.00
# [18:24:57] ✅ EXTRACTED: 'K&ns Nuggets Family Pak 1700gm' (ID: 7013) - Price: 2,185.00
# 📊 [004-P14] ███████░░░░│ 20/33 (60.6%)
# [18:24:58] ✅ EXTRACTED: 'K&ns Burger Patties 400gm' (ID: 7017) - Price: 585.00
# [18:24:58] ✅ EXTRACTED: 'K&ns Combo Wings 850gm' (ID: 7019) - Price: 1,295.00
# [18:24:58] ✅ EXTRACTED: 'K&ns Fiery Fingers 780gm' (ID: 7021) - Price: 1,390.00
# [18:24:58] ✅ EXTRACTED: 'K&ns Breakfast Sausage 32pcs' (ID: 7023) - Price: 1,265.00
# [18:24:59] ✅ EXTRACTED: 'K&ns Shami Kabab 252gm' (ID: 7025) - Price: 500.00
# 📊 [004-P14] ████████░░░│ 25/33 (75.8%)
# [18:24:59] ✅ EXTRACTED: 'K&ns Bologna Slice 616gm' (ID: 7027) - Price: 1,245.00
# [18:24:59] ✅ EXTRACTED: 'K&ns Fajita Topping Filling 65' (ID: 7029) - Price: 1,415.00
# [18:24:59] ✅ EXTRACTED: 'K&ns Haray Bharay Nuggets 1kg' (ID: 7030) - Price: 1,345.00
# [18:25:00] ✅ EXTRACTED: 'K&ns Drumsticks 1000gm' (ID: 7034) - Price: 790.00
# [18:25:00] ✅ EXTRACTED: 'Nurpur Cheddar Cheese 200gm' (ID: 7258) - Price: 645.00
# 📊 [004-P14] ██████████░│ 30/33 (90.9%)
# [18:25:00] ✅ EXTRACTED: 'Adams Pizza Cheese 400gm' (ID: 7274) - Price: 1,255.00
# [18:25:00] ✅ EXTRACTED: 'Special Sandwich Bread Large' (ID: 7277) - Price: 250.00
# [18:25:00] ✅ EXTRACTED: 'Sprite Lemon 350ml' (ID: 7334) - Price: 65.00
# 📊 [004-P14] ███████████│ 33/33 (100.0%)
# [18:25:01] ✅ EXTRACTED: 'Monsalwa Seekh Kabab 18pcs Pou' (ID: 7369) - Price: 750.00
# [18:25:01] 🔄 PAGE COMPLETE: Page 14: 20/33 products extracted
# [18:25:01] 🔄 PAGINATION: Checking for page 15
# [18:25:01] 🔄 PAGINATION: Moving to page 15
# [18:25:01] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:25:05] 🔄 WAITING: Waiting for products to fully load on page 15
# [18:25:05] 🔄 LOAD CHECK: Initial product container found
# [18:25:07] 🔄 LOAD CHECK: 20 product images found
# [18:25:07] 🔄 LOAD CHECK: 22 price elements found
# [18:25:08] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:25:08] 🔄 PAGINATION: Successfully loaded page 15
# [18:25:10] 🔄 PAGE START: Department 004 - Page 15
# [18:25:10] 🔄 WAITING: Waiting for products to fully load on page 15
# [18:25:10] 🔄 LOAD CHECK: Initial product container found
# [18:25:12] 🔄 LOAD CHECK: 20 product images found
# [18:25:12] 🔄 LOAD CHECK: 22 price elements found
# [18:25:13] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:25:13] 🔄 PRODUCTS FOUND: Found 33 products on page 15
# [18:25:13] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:25:13] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:25:13] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:25:13] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P15] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:25:13] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:25:14] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:25:14] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:25:14] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:25:14] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P15] ████░░░░░░░│ 10/33 (30.3%)
# [18:25:14] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:25:14] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:25:14] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:25:14] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:25:15] ✅ EXTRACTED: 'Special Milky Small Bread' (ID: 7379) - Price: 100.00
# 📊 [004-P15] █████░░░░░░│ 15/33 (45.5%)
# [18:25:15] ✅ EXTRACTED: 'Adams Toast Cheese Slice 10pcs' (ID: 7784) - Price: 615.00
# [18:25:15] ✅ EXTRACTED: 'Adams Buffalo Mozzarella Chees' (ID: 7791) - Price: 1,255.00
# [18:25:15] ✅ EXTRACTED: 'Adams Butter 100 Gm' (ID: 7796) - Price: 345.00
# [18:25:15] ✅ EXTRACTED: 'Plain Cake' (ID: 7810) - Price: 575.00
# [18:25:16] ✅ EXTRACTED: 'Dawn Fruit Cake Small 100gm' (ID: 8146) - Price: 100.00
# 📊 [004-P15] ███████░░░░│ 20/33 (60.6%)
# [18:25:16] ✅ EXTRACTED: 'Monsalwa Chicken Nuggets 1kg (' (ID: 8711) - Price: 885.00
# [18:25:16] ✅ EXTRACTED: 'Sabroso Leg Tikka Eco 760+50gm' (ID: 8782) - Price: 1,270.00
# [18:25:16] ✅ EXTRACTED: 'Nestle F/v Kinnow 1ltr' (ID: 8860) - Price: 360.00
# [18:25:16] ✅ EXTRACTED: 'Sabroso Chicken Chapli Kabab 7' (ID: 9042) - Price: 1,090.00
# [18:25:17] ✅ EXTRACTED: 'Eggs Farm Fresh' (ID: 9069) - Price: 399.00
# 📊 [004-P15] ████████░░░│ 25/33 (75.8%)
# [18:25:17] ✅ EXTRACTED: 'Special Pastry' (ID: 9087) - Price: 140.00
# [18:25:17] ✅ EXTRACTED: 'Special Bread Large' (ID: 9097) - Price: 180.00
# [18:25:17] ✅ EXTRACTED: 'Special Bread Mediam' (ID: 9098) - Price: 140.00
# [18:25:17] ✅ EXTRACTED: 'Olpers Full Cream Powder Milk' (ID: 9318) - Price: 1,045.00
# [18:25:18] ✅ EXTRACTED: 'Weetabix Original Biscuits 215' (ID: 9382) - Price: 795.00
# 📊 [004-P15] ██████████░│ 30/33 (90.9%)
# [18:25:18] ✅ EXTRACTED: 'Happy Cow Cheddar Cheese 10sli' (ID: 9404) - Price: 1,335.00
# [18:25:18] ✅ EXTRACTED: 'Happy Cow Cheddar Cheese 8slic' (ID: 9439) - Price: 1,045.00
# [18:25:18] ✅ EXTRACTED: 'Olpers Stw Flav Milk 180ml' (ID: 9533) - Price: 90.00
# 📊 [004-P15] ███████████│ 33/33 (100.0%)
# [18:25:18] ✅ EXTRACTED: 'Olpers Chocolate Milk 180ml' (ID: 9535) - Price: 90.00
# [18:25:18] 🔄 PAGE COMPLETE: Page 15: 20/33 products extracted
# [18:25:18] 🔄 PAGINATION: Checking for page 16
# [18:25:18] 🔄 PAGINATION: Moving to page 16
# [18:25:19] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:25:23] 🔄 WAITING: Waiting for products to fully load on page 16
# [18:25:23] 🔄 LOAD CHECK: Initial product container found
# [18:25:25] 🔄 LOAD CHECK: 20 product images found
# [18:25:25] 🔄 LOAD CHECK: 22 price elements found
# [18:25:26] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:25:26] 🔄 PAGINATION: Successfully loaded page 16
# [18:25:28] 🔄 PAGE START: Department 004 - Page 16
# [18:25:28] 🔄 WAITING: Waiting for products to fully load on page 16
# [18:25:28] 🔄 LOAD CHECK: Initial product container found
# [18:25:30] 🔄 LOAD CHECK: 20 product images found
# [18:25:30] 🔄 LOAD CHECK: 22 price elements found
# [18:25:31] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:25:31] 🔄 PRODUCTS FOUND: Found 33 products on page 16
# [18:25:31] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:25:31] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:25:31] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:25:31] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P16] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:25:31] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:25:31] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:25:31] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:25:32] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:25:32] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P16] ████░░░░░░░│ 10/33 (30.3%)
# [18:25:32] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:25:32] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:25:32] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:25:32] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:25:32] ✅ EXTRACTED: 'Crown Peanut Butter Chunky 510' (ID: 9545) - Price: 1,495.00
# 📊 [004-P16] █████░░░░░░│ 15/33 (45.5%)
# [18:25:33] ✅ EXTRACTED: 'Crown Smooth Creamy Peanut But' (ID: 9546) - Price: 999.00
# [18:25:33] ✅ EXTRACTED: 'Crown Peanut Butter Chunky 340' (ID: 9550) - Price: 999.00
# [18:25:33] ✅ EXTRACTED: 'Monsalwa Crispy Burger Pb 990g' (ID: 10694) - Price: 885.00
# [18:25:33] ✅ EXTRACTED: 'K&ns Fun Nuggets 265gm' (ID: 12375) - Price: 520.00
# [18:25:33] ✅ EXTRACTED: 'K&ns Chicken Tempura 660gm' (ID: 12376) - Price: 1,290.00
# 📊 [004-P16] ███████░░░░│ 20/33 (60.6%)
# [18:25:34] ✅ EXTRACTED: 'Kelloggs Corn Flakes Honey Nut' (ID: 12442) - Price: 1,645.00
# [18:25:34] ✅ EXTRACTED: 'Bunnys Bread Crumbs 200gm' (ID: 13690) - Price: 130.00
# [18:25:34] ✅ EXTRACTED: 'Haleeb Cremyum Thickest Cream' (ID: 13732) - Price: 150.00
# [18:25:34] ✅ EXTRACTED: 'Haleeb Fresh Milk Cream 200ml' (ID: 13733) - Price: 190.00
# [18:25:34] ✅ EXTRACTED: 'Dayfresh Mango Flavour Milk 23' (ID: 13735) - Price: 95.00
# 📊 [004-P16] ████████░░░│ 25/33 (75.8%)
# [18:25:35] ✅ EXTRACTED: 'Dayfresh Pista Zafraan Milk 22' (ID: 13736) - Price: 95.00
# [18:25:35] ✅ EXTRACTED: 'Dayfresh Strawberry Milk 225ml' (ID: 13742) - Price: 95.00
# [18:25:35] ✅ EXTRACTED: 'Dayfresh Lactose Free Milk 1lt' (ID: 13744) - Price: 420.00
# [18:25:35] ✅ EXTRACTED: 'Dayfresh Banana Milk 225ml' (ID: 13748) - Price: 95.00
# [18:25:35] ✅ EXTRACTED: 'Haleeb Tropical Apple Fruit Dr' (ID: 13760) - Price: 210.00
# 📊 [004-P16] ██████████░│ 30/33 (90.9%)
# [18:25:36] ✅ EXTRACTED: 'Haleeb Chaunsa Chaunsa Fruit D' (ID: 13761) - Price: 210.00
# [18:25:36] ✅ EXTRACTED: 'Refresh Punch Juice 1ltr' (ID: 13762) - Price: 220.00
# [18:25:36] ✅ EXTRACTED: 'Refresh Apple Juice 1ltr' (ID: 13772) - Price: 220.00
# 📊 [004-P16] ███████████│ 33/33 (100.0%)
# [18:25:36] ✅ EXTRACTED: 'Refresh Peach Juice 1ltr' (ID: 13778) - Price: 220.00
# [18:25:36] 🔄 PAGE COMPLETE: Page 16: 20/33 products extracted
# [18:25:36] 🔄 PAGINATION: Checking for page 17
# [18:25:36] 🔄 PAGINATION: Moving to page 17
# [18:25:36] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:25:40] 🔄 WAITING: Waiting for products to fully load on page 17
# [18:25:40] 🔄 LOAD CHECK: Initial product container found
# [18:25:42] 🔄 LOAD CHECK: 20 product images found
# [18:25:42] 🔄 LOAD CHECK: 22 price elements found
# [18:25:43] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:25:43] 🔄 PAGINATION: Successfully loaded page 17
# [18:25:45] 🔄 PAGE START: Department 004 - Page 17
# [18:25:45] 🔄 WAITING: Waiting for products to fully load on page 17
# [18:25:45] 🔄 LOAD CHECK: Initial product container found
# [18:25:47] 🔄 LOAD CHECK: 20 product images found
# [18:25:47] 🔄 LOAD CHECK: 22 price elements found
# [18:25:48] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:25:49] 🔄 PRODUCTS FOUND: Found 33 products on page 17
# [18:25:49] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:25:49] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:25:49] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:25:49] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P17] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:25:49] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:25:49] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:25:49] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:25:49] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:25:49] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P17] ████░░░░░░░│ 10/33 (30.3%)
# [18:25:50] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:25:50] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:25:50] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:25:50] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:25:50] ✅ EXTRACTED: 'Fresher Falsa Nectaer Juice 1l' (ID: 13786) - Price: 275.00
# 📊 [004-P17] █████░░░░░░│ 15/33 (45.5%)
# [18:25:50] ✅ EXTRACTED: 'Fresher Peach Juice 1000ml' (ID: 13787) - Price: 275.00
# [18:25:51] ✅ EXTRACTED: 'Fresher Pomegranate Juice 500' (ID: 13789) - Price: 170.00
# [18:25:51] ✅ EXTRACTED: 'Power Full 26 Essentials Drink' (ID: 13822) - Price: 155.00
# [18:25:51] ✅ EXTRACTED: 'Epic Stimulant Drink 250ml' (ID: 13823) - Price: 180.00
# [18:25:51] ✅ EXTRACTED: 'Fruti Orange Drink 240ml' (ID: 13828) - Price: 110.00
# 📊 [004-P17] ███████░░░░│ 20/33 (60.6%)
# [18:25:51] ✅ EXTRACTED: 'Power Full Ginseng Energy Drin' (ID: 13829) - Price: 150.00
# [18:25:52] ✅ EXTRACTED: 'Sprite Drink Tin 250ml' (ID: 13835) - Price: 100.00
# [18:25:52] ✅ EXTRACTED: 'Joiner Grapes Juice 320ml' (ID: 13898) - Price: 295.00
# [18:25:52] ✅ EXTRACTED: 'Great Joiner Mango Juice 320ml' (ID: 13904) - Price: 295.00
# [18:25:52] ✅ EXTRACTED: 'Joiner Strawberry Juice 320ml' (ID: 13909) - Price: 295.00
# 📊 [004-P17] ████████░░░│ 25/33 (75.8%)
# [18:25:52] ✅ EXTRACTED: 'Nestle Milo Powder Tin Pack 40' (ID: 14397) - Price: 2,340.00
# [18:25:53] ✅ EXTRACTED: 'Dry Cake Almond&walnut 1lbs' (ID: 14590) - Price: 649.00
# [18:25:53] ✅ EXTRACTED: 'Fresh Pure Butter 500gm' (ID: 14611) - Price: 550.00
# [18:25:53] ✅ EXTRACTED: 'Amsons Mozzarella Cheese 453gm' (ID: 14727) - Price: 1,290.00
# [18:25:53] ✅ EXTRACTED: 'Whipy Whip Whipping Cream 1kg' (ID: 14825) - Price: 775.00
# 📊 [004-P17] ██████████░│ 30/33 (90.9%)
# [18:25:53] ✅ EXTRACTED: 'K&ns Thunder Fillet 550gm' (ID: 14827) - Price: 1,150.00
# [18:25:54] ✅ EXTRACTED: 'K&ns Chicken Qeema 500gm' (ID: 14851) - Price: 625.00
# [18:25:54] ✅ EXTRACTED: 'K&ns Boneless Handi 500gm' (ID: 14852) - Price: 625.00
# 📊 [004-P17] ███████████│ 33/33 (100.0%)
# [18:25:54] ✅ EXTRACTED: 'Bread & Beyond Tortilla Wrap 0' (ID: 14854) - Price: 365.00
# [18:25:54] 🔄 PAGE COMPLETE: Page 17: 20/33 products extracted
# [18:25:54] 🔄 PAGINATION: Checking for page 18
# [18:25:54] 🔄 PAGINATION: Moving to page 18
# [18:25:54] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:25:58] 🔄 WAITING: Waiting for products to fully load on page 18
# [18:25:58] 🔄 LOAD CHECK: Initial product container found
# [18:26:00] 🔄 LOAD CHECK: 20 product images found
# [18:26:00] 🔄 LOAD CHECK: 22 price elements found
# [18:26:01] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:26:01] 🔄 PAGINATION: Successfully loaded page 18
# [18:26:03] 🔄 PAGE START: Department 004 - Page 18
# [18:26:03] 🔄 WAITING: Waiting for products to fully load on page 18
# [18:26:03] 🔄 LOAD CHECK: Initial product container found
# [18:26:05] 🔄 LOAD CHECK: 20 product images found
# [18:26:05] 🔄 LOAD CHECK: 22 price elements found
# [18:26:06] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:26:06] 🔄 PRODUCTS FOUND: Found 33 products on page 18
# [18:26:06] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:26:06] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:26:07] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:26:07] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P18] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:26:07] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:26:07] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:26:07] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:26:07] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:26:07] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P18] ████░░░░░░░│ 10/33 (30.3%)
# [18:26:07] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:26:07] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:26:08] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:26:08] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:26:08] ✅ EXTRACTED: 'Fresh Mini Pizza' (ID: 14857) - Price: 175.00
# 📊 [004-P18] █████░░░░░░│ 15/33 (45.5%)
# [18:26:08] ✅ EXTRACTED: 'Fresher Mango Nectar Juice 500' (ID: 14861) - Price: 145.00
# [18:26:08] ✅ EXTRACTED: 'Sufi 19-ltr Water Bottle Refil' (ID: 14903) - Price: 320.00
# [18:26:09] ✅ EXTRACTED: 'Adams Cheddar Cheese 200gm' (ID: 15052) - Price: 585.00
# [18:26:09] ✅ EXTRACTED: 'Coca Cola Zero 500ml' (ID: 15152) - Price: 90.00
# [18:26:09] ✅ EXTRACTED: 'Chicken Tikka Kabab' (ID: 15197) - Price: 199.00
# 📊 [004-P18] ███████░░░░│ 20/33 (60.6%)
# [18:26:09] ✅ EXTRACTED: 'Dawn Mac Royal Bun 2pcs' (ID: 15230) - Price: 90.00
# [18:26:09] ✅ EXTRACTED: 'Pakola Ice Cream Soda 500ml' (ID: 15465) - Price: 85.00
# [18:26:10] ✅ EXTRACTED: 'Nestle Milo Choco Powder 300gm' (ID: 16208) - Price: 1,020.00
# [18:26:10] ✅ EXTRACTED: 'K&ns Boti Cut 1000gm' (ID: 16381) - Price: 860.00
# [18:26:10] ✅ EXTRACTED: 'Pizza Small' (ID: 16385) - Price: 250.00
# 📊 [004-P18] ████████░░░│ 25/33 (75.8%)
# [18:26:10] ✅ EXTRACTED: 'Pizza Pestery' (ID: 16386) - Price: 115.00
# [18:26:11] ✅ EXTRACTED: 'Fruit Cake' (ID: 16432) - Price: 250.00
# [18:26:11] ✅ EXTRACTED: 'Dawn Chicken Nuggets 1500gm Po' (ID: 16440) - Price: 1,880.00
# [18:26:11] ✅ EXTRACTED: 'Dawn Fruit Bun' (ID: 16477) - Price: 50.00
# [18:26:11] ✅ EXTRACTED: 'Monsalwa Plain Paratha 20pcs' (ID: 16508) - Price: 875.00
# 📊 [004-P18] ██████████░│ 30/33 (90.9%)
# [18:26:12] ✅ EXTRACTED: 'Nestle Nesvita Hi Calcuim Milk' (ID: 16514) - Price: 385.00
# [18:26:12] ✅ EXTRACTED: 'Adams Butter 200 Gm' (ID: 16547) - Price: 645.00
# [18:26:12] ✅ EXTRACTED: 'Bread Cheese Pizza' (ID: 16569) - Price: 195.00
# 📊 [004-P18] ███████████│ 33/33 (100.0%)
# [18:26:12] ✅ EXTRACTED: 'Fresh Pure Butter 250gm' (ID: 16647) - Price: 275.00
# [18:26:12] 🔄 PAGE COMPLETE: Page 18: 20/33 products extracted
# [18:26:12] 🔄 PAGINATION: Checking for page 19
# [18:26:12] 🔄 PAGINATION: Moving to page 19
# [18:26:13] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:26:17] 🔄 WAITING: Waiting for products to fully load on page 19
# [18:26:17] 🔄 LOAD CHECK: Initial product container found
# [18:26:19] 🔄 LOAD CHECK: 20 product images found
# [18:26:19] 🔄 LOAD CHECK: 22 price elements found
# [18:26:20] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:26:20] 🔄 PAGINATION: Successfully loaded page 19
# [18:26:22] 🔄 PAGE START: Department 004 - Page 19
# [18:26:22] 🔄 WAITING: Waiting for products to fully load on page 19
# [18:26:22] 🔄 LOAD CHECK: Initial product container found
# [18:26:24] 🔄 LOAD CHECK: 20 product images found
# [18:26:24] 🔄 LOAD CHECK: 22 price elements found
# [18:26:25] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:26:25] 🔄 PRODUCTS FOUND: Found 33 products on page 19
# [18:26:25] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:26:25] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:26:25] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:26:25] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P19] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:26:25] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:26:25] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:26:25] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:26:26] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:26:26] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [004-P19] ████░░░░░░░│ 10/33 (30.3%)
# [18:26:26] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:26:26] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:26:26] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:26:26] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:26:26] ✅ EXTRACTED: 'Bread & Beyond White Bread Sma' (ID: 16698) - Price: 120.00
# 📊 [004-P19] █████░░░░░░│ 15/33 (45.5%)
# [18:26:27] ✅ EXTRACTED: 'Bread & Beyond Old Fasion Cake' (ID: 16699) - Price: 330.00
# [18:26:27] ✅ EXTRACTED: 'Bread & Beyond Bar Cake 240gm' (ID: 16722) - Price: 320.00
# [18:26:27] ✅ EXTRACTED: 'Lurpak Butter 200gm Unsalted' (ID: 17097) - Price: 1,245.00
# [18:26:28] ✅ EXTRACTED: 'Dawn Sandwich Bread Large' (ID: 17149) - Price: 280.00
# [18:26:28] ✅ EXTRACTED: 'Bunnys Bran Bread Small' (ID: 17150) - Price: 160.00
# 📊 [004-P19] ███████░░░░│ 20/33 (60.6%)
# [18:26:28] ✅ EXTRACTED: 'Bunnys Large Burger 4pc' (ID: 17153) - Price: 130.00
# [18:26:29] ✅ EXTRACTED: 'Bunnys Milky Bread Large' (ID: 17155) - Price: 200.00
# [18:26:29] ✅ EXTRACTED: 'Dawn Orange Muffin 20gm' (ID: 17159) - Price: 20.00
# [18:26:29] ✅ EXTRACTED: 'Bunnys Queen Cake Chocolate 35' (ID: 17160) - Price: 35.00
# [18:26:30] ✅ EXTRACTED: 'Dawn Vanilla Cake Slices 40gm' (ID: 17162) - Price: 30.00
# 📊 [004-P19] ████████░░░│ 25/33 (75.8%)
# [18:26:30] ✅ EXTRACTED: 'Bunnys Baqar Khani 2pcs' (ID: 17164) - Price: 100.00
# [18:26:30] ✅ EXTRACTED: 'Bunnys Cake Rusk 80gm' (ID: 17166) - Price: 90.00
# [18:26:31] ✅ EXTRACTED: 'Haleeb Asli Full Fat Milk 225m' (ID: 17309) - Price: 75.00
# [18:26:31] ✅ EXTRACTED: 'Bread & Beyond Chocolate Chip' (ID: 17622) - Price: 310.00
# [18:26:31] ✅ EXTRACTED: 'Jenan White Oats 400gm' (ID: 17707) - Price: 760.00
# 📊 [004-P19] ██████████░│ 30/33 (90.9%)
# [18:26:32] ✅ EXTRACTED: 'Complan Vanilla 200gm' (ID: 17748) - Price: 675.00
# [18:26:32] ✅ EXTRACTED: 'Complan Strawberry 200gm' (ID: 17749) - Price: 675.00
# [18:26:32] ✅ EXTRACTED: 'Complan Chocolate 200gm' (ID: 17750) - Price: 675.00
# 📊 [004-P19] ███████████│ 33/33 (100.0%)
# [18:26:33] ✅ EXTRACTED: 'Complan Chocolate 400gm' (ID: 17751) - Price: 1,295.00
# [18:26:33] 🔄 PAGE COMPLETE: Page 19: 20/33 products extracted
# [18:26:33] 🔄 PAGINATION: Checking for page 20
# [18:26:33] 🔄 PAGINATION: Moving to page 20
# [18:26:33] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:26:37] 🔄 WAITING: Waiting for products to fully load on page 20
# [18:26:37] 🔄 LOAD CHECK: Initial product container found
# [18:26:39] 🔄 LOAD CHECK: 20 product images found
# [18:26:39] 🔄 LOAD CHECK: 22 price elements found
# [18:26:40] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:26:40] 🔄 PAGINATION: Successfully loaded page 20
# [18:26:42] 🔄 PAGE START: Department 004 - Page 20
# [18:26:42] 🔄 WAITING: Waiting for products to fully load on page 20
# [18:26:42] 🔄 LOAD CHECK: Initial product container found
# [18:26:44] 🔄 LOAD CHECK: 20 product images found
# [18:26:44] 🔄 LOAD CHECK: 22 price elements found
# [18:26:45] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:26:45] 🔄 PRODUCTS FOUND: Found 33 products on page 20
# [18:26:45] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:26:45] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:26:45] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:26:46] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [004-P20] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:26:46] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:26:46] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:26:46] 🔄 EXTRACTION FAILED: Card 7: No name element found
# ...
# [18:47:54] 🔄 LOAD CHECK: Initial product container found
# [18:47:56] 🔄 LOAD CHECK: 20 product images found
# [18:47:56] 🔄 LOAD CHECK: 22 price elements found
# [18:47:57] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:47:57] 🔄 PAGINATION: Successfully loaded page 22
# [18:47:59] 🔄 PAGE START: Department 006 - Page 22
# [18:47:59] 🔄 WAITING: Waiting for products to fully load on page 22
# [18:47:59] 🔄 LOAD CHECK: Initial product container found
# [18:48:01] 🔄 LOAD CHECK: 20 product images found
# [18:48:01] 🔄 LOAD CHECK: 22 price elements found
# [18:48:02] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:48:02] 🔄 PRODUCTS FOUND: Found 33 products on page 22
# [18:48:02] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:48:02] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:48:02] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:48:02] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [006-P22] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:48:02] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:48:02] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:48:03] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:48:03] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:48:03] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [006-P22] ████░░░░░░░│ 10/33 (30.3%)
# [18:48:03] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:48:03] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:48:03] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:48:03] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:48:03] ✅ EXTRACTED: 'Ariel Original Surf 4kg' (ID: 36483) - Price: 2,235.00
# 📊 [006-P22] █████░░░░░░│ 15/33 (45.5%)
# [18:48:04] ✅ EXTRACTED: 'Fresco Citrus Zest Refill Air' (ID: 36496) - Price: 480.00
# [18:48:04] ✅ EXTRACTED: 'Fresco Aseel Refill Air Freshe' (ID: 36497) - Price: 480.00
# [18:48:04] ✅ EXTRACTED: 'Rose Petal Perfumed Ultra Soft' (ID: 36498) - Price: 375.00
# [18:48:04] ✅ EXTRACTED: 'Fresco Jasmine Refill Air Fres' (ID: 36504) - Price: 480.00
# [18:48:05] ✅ EXTRACTED: 'Fresco 212 Vip Men Refill Air' (ID: 36505) - Price: 480.00
# 📊 [006-P22] ███████░░░░│ 20/33 (60.6%)
# [18:48:05] ✅ EXTRACTED: 'Fresco Polo Refill Air Freshen' (ID: 36506) - Price: 480.00
# [18:48:05] ✅ EXTRACTED: 'Vim Dish Wash Bar 520gm Green' (ID: 36627) - Price: 140.00
# [18:48:05] ✅ EXTRACTED: 'Vim Dish Wash Bar 260gm Green' (ID: 36632) - Price: 70.00
# [18:48:05] ✅ EXTRACTED: 'Harpic Original Toilet Cleaner' (ID: 36662) - Price: 475.00
# [18:48:06] ✅ EXTRACTED: '7cf Leather & Tyre Wax Spray 4' (ID: 36743) - Price: 400.00
# 📊 [006-P22] ████████░░░│ 25/33 (75.8%)
# [18:48:06] ✅ EXTRACTED: '7cf Leather & Tyre Wax Lemon P' (ID: 36744) - Price: 399.00
# [18:48:06] ✅ EXTRACTED: '7cf Leather & Tyre Strawberry' (ID: 36745) - Price: 399.00
# [18:48:06] ✅ EXTRACTED: '7cf Leather & Tyre Jasmine Wax' (ID: 36746) - Price: 399.00
# [18:48:06] ✅ EXTRACTED: '7cf Leather & Tyre Yulan Wax P' (ID: 36747) - Price: 399.00
# [18:48:07] ✅ EXTRACTED: '7cf All Purpose Foamy Cleaner' (ID: 36748) - Price: 440.00
# 📊 [006-P22] ██████████░│ 30/33 (90.9%)
# [18:48:07] ✅ EXTRACTED: '7cf Engine Degreaser Foam 650m' (ID: 36749) - Price: 460.00
# [18:48:07] ✅ EXTRACTED: '7cf Tire Foaming Rejuvenator 6' (ID: 36750) - Price: 440.00
# [18:48:07] ✅ EXTRACTED: 'Good Year Upholstery Cleaner 7' (ID: 36751) - Price: 1,550.00
# 📊 [006-P22] ███████████│ 33/33 (100.0%)
# [18:48:07] ✅ EXTRACTED: 'Elegant Cotton Buds Jar 300pcs' (ID: 36787) - Price: 300.00
# [18:48:07] 🔄 PAGE COMPLETE: Page 22: 20/33 products extracted
# [18:48:07] 🔄 PAGINATION: Checking for page 23
# [18:48:07] 🔄 PAGINATION: Moving to page 23
# [18:48:07] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:48:11] 🔄 WAITING: Waiting for products to fully load on page 23
# [18:48:11] 🔄 LOAD CHECK: Initial product container found
# [18:48:13] 🔄 LOAD CHECK: 20 product images found
# [18:48:13] 🔄 LOAD CHECK: 22 price elements found
# [18:48:14] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:48:14] 🔄 PAGINATION: Successfully loaded page 23
# [18:48:16] 🔄 PAGE START: Department 006 - Page 23
# [18:48:16] 🔄 WAITING: Waiting for products to fully load on page 23
# [18:48:16] 🔄 LOAD CHECK: Initial product container found
# [18:48:19] 🔄 LOAD CHECK: 20 product images found
# [18:48:19] 🔄 LOAD CHECK: 22 price elements found
# [18:48:20] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:48:20] 🔄 PRODUCTS FOUND: Found 33 products on page 23
# [18:48:20] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:48:20] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:48:20] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:48:20] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [006-P23] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:48:20] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:48:20] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:48:20] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:48:20] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:48:21] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [006-P23] ████░░░░░░░│ 10/33 (30.3%)
# [18:48:21] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:48:21] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:48:21] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:48:21] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:48:21] ✅ EXTRACTED: 'Number 1 Bloom Washing Powder' (ID: 36842) - Price: 140.00
# 📊 [006-P23] █████░░░░░░│ 15/33 (45.5%)
# [18:48:21] ✅ EXTRACTED: 'Power Plus Mosquito Mat Heater' (ID: 37065) - Price: 299.00
# [18:48:22] ✅ EXTRACTED: 'Power Plus Black Jumbo Coil 5p' (ID: 37066) - Price: 155.00
# [18:48:22] ✅ EXTRACTED: 'Power Plus Blue Liquid 75ml' (ID: 37096) - Price: 80.00
# [18:48:22] ✅ EXTRACTED: 'Jay Namaz' (ID: 37205) - Price: 1,499.04
# [18:48:22] ✅ EXTRACTED: 'Ariel Original Surf 1kg' (ID: 37357) - Price: 545.00
# 📊 [006-P23] ███████░░░░│ 20/33 (60.6%)
# [18:48:22] ✅ EXTRACTED: 'Ariel Downy Surf 3kg' (ID: 37436) - Price: 1,650.00
# [18:48:23] ✅ EXTRACTED: 'Ariel Downy Surf 4kg' (ID: 37437) - Price: 2,190.00
# [18:48:23] ✅ EXTRACTED: 'Lemon Max Lime Dish Washing Pa' (ID: 37438) - Price: 225.00
# [18:48:23] ✅ EXTRACTED: 'Lemon Max Powder 400gm Offer P' (ID: 37488) - Price: 80.00
# [18:48:23] ✅ EXTRACTED: 'Lemon Max Lemon Juice Powder C' (ID: 37647) - Price: 150.00
# 📊 [006-P23] ████████░░░│ 25/33 (75.8%)
# [18:48:23] ✅ EXTRACTED: 'Osome Glee Kitchen Towel Singl' (ID: 37786) - Price: 285.00
# [18:48:24] ✅ EXTRACTED: 'Osome Clean It Kitchen Towel' (ID: 37822) - Price: 670.00
# [18:48:24] ✅ EXTRACTED: 'Osome Glee Kitchen Towel Twin' (ID: 37823) - Price: 520.00
# [18:48:24] ✅ EXTRACTED: 'Osome Royal Pop Up Tissue' (ID: 37826) - Price: 230.00
# [18:48:24] ✅ EXTRACTED: 'Ariel Original Washing Powder' (ID: 37838) - Price: 50.00
# 📊 [006-P23] ██████████░│ 30/33 (90.9%)
# [18:48:24] ✅ EXTRACTED: 'Ariel Downy Surf 1kg' (ID: 37914) - Price: 565.00
# [18:48:25] ✅ EXTRACTED: 'Osome Table Napkin 100sheets 2' (ID: 38057) - Price: 230.00
# [18:48:25] ✅ EXTRACTED: 'Osome Jumbo Roll' (ID: 38058) - Price: 995.00
# 📊 [006-P23] ███████████│ 33/33 (100.0%)
# [18:48:25] ✅ EXTRACTED: 'Osome Maxi Roll Tissue' (ID: 38059) - Price: 1,295.00
# [18:48:25] 🔄 PAGE COMPLETE: Page 23: 20/33 products extracted
# [18:48:25] 🔄 PAGINATION: Checking for page 24
# [18:48:25] 🔄 PAGINATION: Moving to page 24
# [18:48:25] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:48:29] 🔄 WAITING: Waiting for products to fully load on page 24
# [18:48:29] 🔄 LOAD CHECK: Initial product container found
# [18:48:31] 🔄 LOAD CHECK: 20 product images found
# [18:48:31] 🔄 LOAD CHECK: 22 price elements found
# [18:48:32] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:48:32] 🔄 PAGINATION: Successfully loaded page 24
# [18:48:34] 🔄 PAGE START: Department 006 - Page 24
# [18:48:34] 🔄 WAITING: Waiting for products to fully load on page 24
# [18:48:34] 🔄 LOAD CHECK: Initial product container found
# [18:48:36] 🔄 LOAD CHECK: 20 product images found
# [18:48:36] 🔄 LOAD CHECK: 22 price elements found
# [18:48:37] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:48:37] 🔄 PRODUCTS FOUND: Found 33 products on page 24
# [18:48:37] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:48:37] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:48:38] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:48:38] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [006-P24] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:48:38] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:48:38] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:48:38] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:48:38] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:48:38] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [006-P24] ████░░░░░░░│ 10/33 (30.3%)
# [18:48:38] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:48:38] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:48:39] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:48:39] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:48:39] ✅ EXTRACTED: 'Disposible Container Black 100' (ID: 38113) - Price: 170.00
# 📊 [006-P24] █████░░░░░░│ 15/33 (45.5%)
# [18:48:39] ✅ EXTRACTED: 'Disposible Container Black 500' (ID: 38114) - Price: 140.00
# [18:48:39] ✅ EXTRACTED: 'Fresco Lavender Air Freshener' (ID: 38186) - Price: 330.00
# [18:48:39] ✅ EXTRACTED: 'Fresco Dunhill Desire Air Fres' (ID: 38187) - Price: 330.00
# [18:48:40] ✅ EXTRACTED: 'Surf Excel Washing Powder 4.5k' (ID: 38313) - Price: 2,450.00
# [18:48:40] ✅ EXTRACTED: 'Sunlight Clean Fresh Jasmine 1' (ID: 38358) - Price: 270.00
# 📊 [006-P24] ███████░░░░│ 20/33 (60.6%)
# [18:48:40] ✅ EXTRACTED: 'Hankies Premium Soft Pack Tiss' (ID: 38393) - Price: 365.00
# [18:48:40] ✅ EXTRACTED: 'Surf Excel Washing Powder 3kg' (ID: 38407) - Price: 1,624.95
# [18:48:40] ✅ EXTRACTED: 'Vim Dish Washing Bar Green 75g' (ID: 38446) - Price: 25.00
# [18:48:41] ✅ EXTRACTED: 'Selpak Tissue Paper 3ply 48pcs' (ID: 38455) - Price: 540.00
# [18:48:41] ✅ EXTRACTED: 'Breeo Detergent 500gm' (ID: 38459) - Price: 265.00
# 📊 [006-P24] ████████░░░│ 25/33 (75.8%)
# [18:48:41] ✅ EXTRACTED: 'Xtra Kleen Soft Pack Tissue' (ID: 38473) - Price: 260.00
# [18:48:41] ✅ EXTRACTED: 'Osome Party Pack White Tissue' (ID: 38498) - Price: 255.00
# [18:48:41] ✅ EXTRACTED: 'Osome Blessing Soft Tissue 300' (ID: 38500) - Price: 260.00
# [18:48:42] ✅ EXTRACTED: 'Fine Smile Toilet Roll 4pc' (ID: 38501) - Price: 420.00
# [18:48:42] ✅ EXTRACTED: 'Fine Smile Paper Towel 1pc' (ID: 38503) - Price: 278.00
# 📊 [006-P24] ██████████░│ 30/33 (90.9%)
# [18:48:42] ✅ EXTRACTED: 'Fine Smile Al Oud Tissue 150*2' (ID: 38504) - Price: 315.00
# [18:48:42] ✅ EXTRACTED: 'Fine Smile Multi Collor Tissue' (ID: 38505) - Price: 320.00
# [18:48:43] ✅ EXTRACTED: 'Hankies Premium Perfumed Soft' (ID: 38507) - Price: 385.02
# 📊 [006-P24] ███████████│ 33/33 (100.0%)
# [18:48:43] ✅ EXTRACTED: 'Hankies Toilet Tissues Eco Pac' (ID: 38508) - Price: 845.00
# [18:48:43] 🔄 PAGE COMPLETE: Page 24: 20/33 products extracted
# [18:48:43] 🔄 PAGINATION: Checking for page 25
# [18:48:43] 🔄 PAGINATION: Moving to page 25
# [18:48:43] 🔄 WAITING: Waiting for new page to load after pagination...
# [18:48:47] 🔄 WAITING: Waiting for products to fully load on page 25
# [18:48:47] 🔄 LOAD CHECK: Initial product container found
# [18:48:49] 🔄 LOAD CHECK: 20 product images found
# [18:48:49] 🔄 LOAD CHECK: 22 price elements found
# [18:48:50] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:48:50] 🔄 PAGINATION: Successfully loaded page 25
# [18:48:52] 🔄 PAGE START: Department 006 - Page 25
# [18:48:52] 🔄 WAITING: Waiting for products to fully load on page 25
# [18:48:52] 🔄 LOAD CHECK: Initial product container found
# [18:48:54] 🔄 LOAD CHECK: 20 product images found
# [18:48:54] 🔄 LOAD CHECK: 22 price elements found
# [18:48:55] 🔄 LOAD COMPLETE: All products fully loaded and ready for scraping
# [18:48:55] 🔄 PRODUCTS FOUND: Found 33 products on page 25
# [18:48:55] 🔄 EXTRACTION FAILED: Card 1: No name element found
# [18:48:55] 🔄 EXTRACTION FAILED: Card 2: No name element found
# [18:48:55] 🔄 EXTRACTION FAILED: Card 3: No name element found
# [18:48:55] 🔄 EXTRACTION FAILED: Card 4: No name element found
# 📊 [006-P25] ██░░░░░░░░░│ 5/33 (15.2%)
# [18:48:55] 🔄 EXTRACTION FAILED: Card 5: No name element found
# [18:48:56] 🔄 EXTRACTION FAILED: Card 6: No name element found
# [18:48:56] 🔄 EXTRACTION FAILED: Card 7: No name element found
# [18:48:56] 🔄 EXTRACTION FAILED: Card 8: No name element found
# [18:48:56] 🔄 EXTRACTION FAILED: Card 9: No name element found
# 📊 [006-P25] ████░░░░░░░│ 10/33 (30.3%)
# [18:48:56] 🔄 EXTRACTION FAILED: Card 10: No name element found
# [18:48:56] 🔄 EXTRACTION FAILED: Card 11: No name element found
# [18:48:56] 🔄 EXTRACTION FAILED: Card 12: No name element found
# [18:48:56] 🔄 EXTRACTION FAILED: Card 13: No name element found
# [18:48:57] ✅ EXTRACTED: 'Sunlight Clean Fresh Green 1kg' (ID: 38602) - Price: 270.00
# 📊 [006-P25] █████░░░░░░│ 15/33 (45.5%)
# [18:48:57] ✅ EXTRACTED: 'Surf Excel Surf 2kg' (ID: 38629) - Price: 999.00
# [18:48:57] ✅ EXTRACTED: 'Astonish Kitchen Cleaner 750ml' (ID: 38661) - Price: 799.00
# [18:48:57] ✅ EXTRACTED: 'Astonish Orange Grove Surface' (ID: 38662) - Price: 799.00
# [18:48:57] ✅ EXTRACTED: 'Astonsih Window & Glass Cleane' (ID: 38663) - Price: 799.00
# [18:48:58] ✅ EXTRACTED: 'Astonish Multi Purpose Bleach' (ID: 38664) - Price: 799.00
# 📊 [006-P25] ███████░░░░│ 20/33 (60.6%)
# [18:48:58] ✅ EXTRACTED: 'Astonish Lavender Blossom Surf' (ID: 38669) - Price: 889.00
# [18:48:58] ✅ EXTRACTED: 'Astonish Berry Harvest Surface' (ID: 38670) - Price: 1,230.00
# [18:48:58] ✅ EXTRACTED: 'Astonish Herbal Escape Surface' (ID: 38671) - Price: 920.00
# [18:48:58] ✅ EXTRACTED: 'Astonish Morning Dew Surface C' (ID: 38672) - Price: 1,230.00
# [18:48:59] ✅ EXTRACTED: 'Surf Excel Surf 1kg' (ID: 38692) - Price: 530.00
# 📊 [006-P25] ████████░░░│ 25/33 (75.8%)
# [18:48:59] ✅ EXTRACTED: 'Top-tip Cotton Buds 100pcs' (ID: 38715) - Price: 110.00
# [18:48:59] ✅ EXTRACTED: 'Lemon Max Lime Paste 200gm' (ID: 38869) - Price: 135.00
# [18:48:59] ✅ EXTRACTED: 'Vista Detergent 3kg' (ID: 38897) - Price: 1,499.00
# [18:49:00] ✅ EXTRACTED: 'Vista Detergent 5kg' (ID: 38898) - Price: 2,399.00
# [18:49:00] ✅ EXTRACTED: 'Vista Detergent Powder 500gm' (ID: 38939) - Price: 260.00
# 📊 [006-P25] ██████████░│ 30/33 (90.9%)
# [18:49:00] ✅ EXTRACTED: 'Lemon Max Dishwash Liquid 750m' (ID: 38956) - Price: 385.00
# [18:49:00] ✅ EXTRACTED: 'Surf Excel Detergent 500gm' (ID: 38983) - Price: 255.01
# [18:49:01] ✅ EXTRACTED: 'Surf Excel Expert White 500gm' (ID: 38984) - Price: 300.00
# 📊 [006-P25] ███████████│ 33/33 (100.0%)
# [18:49:01] ✅ EXTRACTED: 'Surf Excel Expert White 1kg' (ID: 38985) - Price: 600.00
# [18:49:01] 🔄 PAGE COMPLETE: Page 25: 20/33 products extracted
# [18:49:01] 🔄 PAGINATION: Checking for page 26
# [18:49:01] 🔄 PAGINATION: No next button found
# [18:49:01] 🔄 DEPARTMENT COMPLETE: No more pages after page 25
# ────────────────────────────────────────────────────────────────────────────────
# 🏁 DEPARTMENT 006 COMPLETED!
# 📦 Total products: 500
# ⏱️  Time taken: 450.63 seconds
# ────────────────────────────────────────────────────────────────────────────────
# [18:49:01] 🔄 PAGE CLOSED: Department 006 browser page closed
# [18:49:01] 🔄 CSV SAVED: 6060 products saved to rahim_store_products_20251101_171647.csv
#
# ════════════════════════════════════════════════════════════════════════════════
# 🎉 SCRAPING COMPLETED - FINAL SUMMARY
# ════════════════════════════════════════════════════════════════════════════════
# ⏱️  Total duration: 5534.04 seconds
# 📊 Total products: 6060
# ❌ Failed extractions: 0
# 💾 Output file: rahim_store_products_20251101_171647.csv
#
# 📈 DEPARTMENT BREAKDOWN:
#    └── Department 001: 1820 products
#    └── Department 002: 2000 products
#    └── Department 003: 380 products
#    └── Department 004: 860 products
#    └── Department 005: 500 products
#    └── Department 006: 500 products
#
# 📊 Success rate: 100.0%
# ════════════════════════════════════════════════════════════════════════════════
# [18:49:01] 🔄 BROWSER CLOSED: All resources cleaned up

# %%
# !pip install playwright
# !playwright install
# Out:
# Collecting playwright
#   Downloading playwright-1.55.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Collecting pyee<14,>=13 (from playwright)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from playwright) (3.2.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from pyee<14,>=13->playwright) (4.15.0)
# Downloading playwright-1.55.0-py3-none-manylinux1_x86_64.whl (45.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 MB 18.5 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.55.0 pyee-13.0.0
# Downloading Chromium 140.0.7339.16 (playwright build v1187) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1187/chromium-linux.zip
# 173.7 MiB [] 0% 0.0s173.7 MiB [] 0% 25.0s173.7 MiB [] 0% 25.3s173.7 MiB [] 0% 20.1s173.7 MiB [] 0% 14.8s173.7 MiB [] 0% 10.3s173.7 MiB [] 1% 7.9s173.7 MiB [] 1% 6.7s173.7 MiB [] 2% 6.1s173.7 MiB [] 2% 5.4s173.7 MiB [] 3% 4.6s173.7 MiB [] 4% 3.9s173.7 MiB [] 5% 3.5s173.7 MiB [] 5% 3.7s173.7 MiB [] 6% 3.4s173.7 MiB [] 6% 3.3s173.7 MiB [] 7% 3.1s173.7 MiB [] 8% 3.1s173.7 MiB [] 9% 2.9s173.7 MiB [] 9% 2.8s173.7 MiB [] 10% 2.7s173.7 MiB [] 11% 2.6s173.7 MiB [] 13% 2.4s173.7 MiB [] 14% 2.3s173.7 MiB [] 15% 2.2s173.7 MiB [] 16% 2.1s173.7 MiB [] 17% 2.0s173.7 MiB [] 18% 1.9s173.7 MiB [] 19% 1.9s173.7 MiB [] 20% 1.8s173.7 MiB [] 21% 1.8s173.7 MiB [] 22% 1.8s173.7 MiB [] 24% 1.7s173.7 MiB [] 25% 1.6s173.7 MiB [] 27% 1.6s173.7 MiB [] 28% 1.5s173.7 MiB [] 29% 1.5s173.7 MiB [] 30% 1.4s173.7 MiB [] 31% 1.4s173.7 MiB [] 33% 1.3s173.7 MiB [] 34% 1.3s173.7 MiB [] 35% 1.3s173.7 MiB [] 36% 1.2s173.7 MiB [] 38% 1.2s173.7 MiB [] 39% 1.1s173.7 MiB [] 40% 1.1s173.7 MiB [] 41% 1.1s173.7 MiB [] 42% 1.1s173.7 MiB [] 43% 1.0s173.7 MiB [] 45% 1.0s173.7 MiB [] 47% 0.9s173.7 MiB [] 48% 0.9s173.7 MiB [] 49% 0.9s173.7 MiB [] 50% 0.9s173.7 MiB [] 51% 0.9s173.7 MiB [] 52% 0.9s173.7 MiB [] 53% 0.8s173.7 MiB [] 54% 0.8s173.7 MiB [] 55% 0.8s173.7 MiB [] 57% 0.8s173.7 MiB [] 58% 0.7s173.7 MiB [] 60% 0.7s173.7 MiB [] 61% 0.6s173.7 MiB [] 62% 0.6s173.7 MiB [] 63% 0.6s173.7 MiB [] 64% 0.6s173.7 MiB [] 65% 0.6s173.7 MiB [] 66% 0.6s173.7 MiB [] 67% 0.6s173.7 MiB [] 68% 0.5s173.7 MiB [] 69% 0.5s173.7 MiB [] 71% 0.5s173.7 MiB [] 72% 0.5s173.7 MiB [] 74% 0.4s173.7 MiB [] 75% 0.4s173.7 MiB [] 76% 0.4s173.7 MiB [] 78% 0.4s173.7 MiB [] 80% 0.3s173.7 MiB [] 81% 0.3s173.7 MiB [] 83% 0.3s173.7 MiB [] 84% 0.2s173.7 MiB [] 86% 0.2s173.7 MiB [] 87% 0.2s173.7 MiB [] 89% 0.2s173.7 MiB [] 90% 0.1s173.7 MiB [] 92% 0.1s173.7 MiB [] 93% 0.1s173.7 MiB [] 94% 0.1s173.7 MiB [] 96% 0.1s173.7 MiB [] 98% 0.0s173.7 MiB [] 99% 0.0s173.7 MiB [] 100% 0.0s
# Chromium 140.0.7339.16 (playwright build v1187) downloaded to /root/.cache/ms-playwright/chromium-1187
# Downloading Chromium Headless Shell 140.0.7339.16 (playwright build v1187) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1187/chromium-headless-shell-linux.zip
# 104.3 MiB [] 0% 0.0s104.3 MiB [] 0% 27.2s104.3 MiB [] 0% 27.8s104.3 MiB [] 0% 19.2s104.3 MiB [] 0% 14.8s104.3 MiB [] 0% 10.9s104.3 MiB [] 1% 7.9s104.3 MiB [] 2% 5.5s104.3 MiB [] 3% 4.0s104.3 MiB [] 4% 3.2s104.3 MiB [] 6% 2.6s104.3 MiB [] 7% 2.3s104.3 MiB [] 8% 2.2s104.3 MiB [] 9% 2.2s104.3 MiB [] 10% 2.1s104.3 MiB [] 11% 2.0s104.3 MiB [] 13% 1.8s104.3 MiB [] 14% 1.8s104.3 MiB [] 15% 1.7s104.3 MiB [] 15% 1.8s104.3 MiB [] 17% 1.6s104.3 MiB [] 18% 1.6s104.3 MiB [] 20% 1.5s104.3 MiB [] 22% 1.4s104.3 MiB [] 24% 1.3s104.3 MiB [] 26% 1.2s104.3 MiB [] 28% 1.1s104.3 MiB [] 29% 1.1s104.3 MiB [] 31% 1.0s104.3 MiB [] 33% 1.0s104.3 MiB [] 36% 0.9s104.3 MiB [] 37% 0.9s104.3 MiB [] 39% 0.8s104.3 MiB [] 42% 0.8s104.3 MiB [] 44% 0.7s104.3 MiB [] 46% 0.7s104.3 MiB [] 48% 0.7s104.3 MiB [] 50% 0.6s104.3 MiB [] 52% 0.6s104.3 MiB [] 55% 0.5s104.3 MiB [] 57% 0.5s104.3 MiB [] 59% 0.5s104.3 MiB [] 61% 0.5s104.3 MiB [] 63% 0.4s104.3 MiB [] 65% 0.4s104.3 MiB [] 66% 0.4s104.3 MiB [] 67% 0.4s104.3 MiB [] 68% 0.4s104.3 MiB [] 70% 0.3s104.3 MiB [] 72% 0.3s104.3 MiB [] 74% 0.3s104.3 MiB [] 76% 0.3s104.3 MiB [] 77% 0.2s104.3 MiB [] 79% 0.2s104.3 MiB [] 81% 0.2s104.3 MiB [] 83% 0.2s104.3 MiB [] 86% 0.2s104.3 MiB [] 87% 0.1s104.3 MiB [] 89% 0.1s104.3 MiB [] 92% 0.1s104.3 MiB [] 93% 0.1s104.3 MiB [] 95% 0.0s104.3 MiB [] 97% 0.0s104.3 MiB [] 99% 0.0s104.3 MiB [] 100% 0.0s
# Chromium Headless Shell 140.0.7339.16 (playwright build v1187) downloaded to /root/.cache/ms-playwright/chromium_headless_shell-1187
# Downloading Firefox 141.0 (playwright build v1490) from https://cdn.playwright.dev/dbazure/download/playwright/builds/firefox/1490/firefox-ubuntu-22.04.zip
# 96 MiB [] 0% 0.0s96 MiB [] 0% 17.4s96 MiB [] 0% 19.4s96 MiB [] 0% 13.5s96 MiB [] 0% 9.9s96 MiB [] 1% 6.7s96 MiB [] 1% 4.8s96 MiB [] 3% 3.5s96 MiB [] 4% 3.0s96 MiB [] 5% 2.5s96 MiB [] 6% 2.2s96 MiB [] 8% 2.0s96 MiB [] 9% 1.9s96 MiB [] 9% 2.0s96 MiB [] 10% 2.0s96 MiB [] 11% 1.9s96 MiB [] 11% 2.0s96 MiB [] 12% 2.0s96 MiB [] 12% 2.1s96 MiB [] 12% 2.3s96 MiB [] 13% 2.2s96 MiB [] 14% 2.2s96 MiB [] 15% 2.3s96 MiB [] 16% 2.1s96 MiB [] 17% 2.1s96 MiB [] 19% 1.9s96 MiB [] 20% 1.9s96 MiB [] 22% 1.8s96 MiB [] 24% 1.7s96 MiB [] 25% 1.6s96 MiB [] 26% 1.5s96 MiB [] 28% 1.5s96 MiB [] 29% 1.4s96 MiB [] 30% 1.4s96 MiB [] 32% 1.3s96 MiB [] 33% 1.3s96 MiB [] 34% 1.2s96 MiB [] 36% 1.2s96 MiB [] 38% 1.1s96 MiB [] 39% 1.1s96 MiB [] 40% 1.1s96 MiB [] 41% 1.1s96 MiB [] 42% 1.0s96 MiB [] 43% 1.0s96 MiB [] 45% 1.0s96 MiB [] 47% 0.9s96 MiB [] 48% 0.9s96 MiB [] 50% 0.8s96 MiB [] 52% 0.8s96 MiB [] 53% 0.8s96 MiB [] 54% 0.7s96 MiB [] 56% 0.7s96 MiB [] 58% 0.7s96 MiB [] 59% 0.6s96 MiB [] 61% 0.6s96 MiB [] 62% 0.6s96 MiB [] 64% 0.6s96 MiB [] 65% 0.5s96 MiB [] 66% 0.5s96 MiB [] 68% 0.5s96 MiB [] 70% 0.5s96 MiB [] 72% 0.4s96 MiB [] 74% 0.4s96 MiB [] 75% 0.4s96 MiB [] 76% 0.3s96 MiB [] 77% 0.3s96 MiB [] 79% 0.3s96 MiB [] 80% 0.3s96 MiB [] 81% 0.3s96 MiB [] 82% 0.3s96 MiB [] 83% 0.2s96 MiB [] 85% 0.2s96 MiB [] 86% 0.2s96 MiB [] 88% 0.2s96 MiB [] 91% 0.1s96 MiB [] 93% 0.1s96 MiB [] 95% 0.1s96 MiB [] 97% 0.0s96 MiB [] 100% 0.0s
# Firefox 141.0 (playwright build v1490) downloaded to /root/.cache/ms-playwright/firefox-1490
# Downloading Webkit 26.0 (playwright build v2203) from https://cdn.playwright.dev/dbazure/download/playwright/builds/webkit/2203/webkit-ubuntu-22.04.zip
# 94.6 MiB [] 0% 0.0s94.6 MiB [] 0% 17.2s94.6 MiB [] 0% 18.3s94.6 MiB [] 0% 13.0s94.6 MiB [] 0% 9.4s94.6 MiB [] 1% 6.2s94.6 MiB [] 2% 4.3s94.6 MiB [] 3% 3.0s94.6 MiB [] 5% 2.3s94.6 MiB [] 6% 2.0s94.6 MiB [] 8% 1.8s94.6 MiB [] 9% 1.6s94.6 MiB [] 10% 1.8s94.6 MiB [] 11% 1.7s94.6 MiB [] 12% 1.7s94.6 MiB [] 13% 1.6s94.6 MiB [] 14% 1.5s94.6 MiB [] 16% 1.4s94.6 MiB [] 17% 1.4s94.6 MiB [] 19% 1.3s94.6 MiB [] 20% 1.3s94.6 MiB [] 21% 1.3s94.6 MiB [] 22% 1.2s94.6 MiB [] 25% 1.1s94.6 MiB [] 27% 1.0s94.6 MiB [] 28% 1.0s94.6 MiB [] 30% 1.0s94.6 MiB [] 31% 1.0s94.6 MiB [] 33% 0.9s94.6 MiB [] 34% 0.9s94.6 MiB [] 36% 0.9s94.6 MiB [] 37% 0.9s94.6 MiB [] 38% 0.8s94.6 MiB [] 39% 0.8s94.6 MiB [] 40% 0.8s94.6 MiB [] 43% 0.8s94.6 MiB [] 45% 0.7s94.6 MiB [] 48% 0.7s94.6 MiB [] 50% 0.6s94.6 MiB [] 53% 0.6s94.6 MiB [] 54% 0.6s94.6 MiB [] 56% 0.5s94.6 MiB [] 59% 0.5s94.6 MiB [] 61% 0.4s94.6 MiB [] 63% 0.4s94.6 MiB [] 65% 0.4s94.6 MiB [] 67% 0.4s94.6 MiB [] 70% 0.3s94.6 MiB [] 73% 0.3s94.6 MiB [] 75% 0.3s94.6 MiB [] 77% 0.2s94.6 MiB [] 80% 0.2s94.6 MiB [] 82% 0.2s94.6 MiB [] 85% 0.1s94.6 MiB [] 87% 0.1s94.6 MiB [] 90% 0.1s94.6 MiB [] 91% 0.1s94.6 MiB [] 93% 0.1s94.6 MiB [] 96% 0.0s94.6 MiB [] 98% 0.0s94.6 MiB [] 100% 0.0s
# Webkit 26.0 (playwright build v2203) downloaded to /root/.cache/ms-playwright/webkit-2203
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# 2.3 MiB [] 0% 0.0s2.3 MiB [] 2% 0.7s2.3 MiB [] 6% 0.6s2.3 MiB [] 12% 0.4s2.3 MiB [] 20% 0.3s2.3 MiB [] 33% 0.2s2.3 MiB [] 52% 0.1s2.3 MiB [] 85% 0.0s2.3 MiB [] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libavif.so.13                                    ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:934:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:1056:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:1045:7)
#     at async i.<anonymous> (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/cli/program.js:217:7)
