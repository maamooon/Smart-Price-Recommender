# %%
# !pip install playwright
# !playwright install
# Out:
# Collecting playwright
#   Downloading playwright-1.55.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Collecting pyee<14,>=13 (from playwright)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from playwright) (3.2.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from pyee<14,>=13->playwright) (4.15.0)
# Downloading playwright-1.55.0-py3-none-manylinux1_x86_64.whl (45.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 MB 22.0 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.55.0 pyee-13.0.0
# Downloading Chromium 140.0.7339.16 (playwright build v1187) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1187/chromium-linux.zip
# 173.7 MiB [] 0% 11.5s173.7 MiB [] 0% 26.5s173.7 MiB [] 0% 23.6s173.7 MiB [] 0% 17.0s173.7 MiB [] 0% 11.2s173.7 MiB [] 0% 9.5s173.7 MiB [] 1% 8.6s173.7 MiB [] 1% 6.4s173.7 MiB [] 2% 4.9s173.7 MiB [] 3% 4.0s173.7 MiB [] 4% 3.5s173.7 MiB [] 5% 3.3s173.7 MiB [] 5% 3.5s173.7 MiB [] 6% 3.2s173.7 MiB [] 7% 3.1s173.7 MiB [] 7% 2.9s173.7 MiB [] 8% 2.9s173.7 MiB [] 9% 2.7s173.7 MiB [] 10% 2.7s173.7 MiB [] 10% 2.6s173.7 MiB [] 11% 2.5s173.7 MiB [] 12% 2.5s173.7 MiB [] 13% 2.4s173.7 MiB [] 15% 2.2s173.7 MiB [] 16% 2.1s173.7 MiB [] 17% 2.0s173.7 MiB [] 18% 2.0s173.7 MiB [] 19% 1.9s173.7 MiB [] 20% 1.8s173.7 MiB [] 21% 1.8s173.7 MiB [] 21% 1.9s173.7 MiB [] 23% 1.8s173.7 MiB [] 24% 1.7s173.7 MiB [] 26% 1.6s173.7 MiB [] 27% 1.5s173.7 MiB [] 29% 1.4s173.7 MiB [] 30% 1.4s173.7 MiB [] 32% 1.3s173.7 MiB [] 33% 1.3s173.7 MiB [] 34% 1.2s173.7 MiB [] 36% 1.2s173.7 MiB [] 37% 1.2s173.7 MiB [] 39% 1.1s173.7 MiB [] 40% 1.1s173.7 MiB [] 42% 1.0s173.7 MiB [] 43% 1.0s173.7 MiB [] 44% 1.0s173.7 MiB [] 46% 0.9s173.7 MiB [] 48% 0.9s173.7 MiB [] 49% 0.8s173.7 MiB [] 51% 0.8s173.7 MiB [] 52% 0.8s173.7 MiB [] 54% 0.7s173.7 MiB [] 55% 0.7s173.7 MiB [] 56% 0.7s173.7 MiB [] 57% 0.7s173.7 MiB [] 59% 0.6s173.7 MiB [] 61% 0.6s173.7 MiB [] 62% 0.6s173.7 MiB [] 63% 0.6s173.7 MiB [] 64% 0.6s173.7 MiB [] 65% 0.6s173.7 MiB [] 66% 0.6s173.7 MiB [] 67% 0.5s173.7 MiB [] 68% 0.5s173.7 MiB [] 69% 0.5s173.7 MiB [] 70% 0.5s173.7 MiB [] 71% 0.5s173.7 MiB [] 72% 0.5s173.7 MiB [] 73% 0.5s173.7 MiB [] 74% 0.5s173.7 MiB [] 75% 0.4s173.7 MiB [] 76% 0.4s173.7 MiB [] 77% 0.4s173.7 MiB [] 78% 0.4s173.7 MiB [] 79% 0.4s173.7 MiB [] 80% 0.4s173.7 MiB [] 81% 0.3s173.7 MiB [] 82% 0.3s173.7 MiB [] 83% 0.3s173.7 MiB [] 84% 0.3s173.7 MiB [] 85% 0.3s173.7 MiB [] 86% 0.2s173.7 MiB [] 87% 0.2s173.7 MiB [] 88% 0.2s173.7 MiB [] 89% 0.2s173.7 MiB [] 90% 0.2s173.7 MiB [] 91% 0.2s173.7 MiB [] 92% 0.1s173.7 MiB [] 93% 0.1s173.7 MiB [] 94% 0.1s173.7 MiB [] 95% 0.1s173.7 MiB [] 96% 0.1s173.7 MiB [] 97% 0.1s173.7 MiB [] 97% 0.0s173.7 MiB [] 99% 0.0s173.7 MiB [] 100% 0.0s
# Chromium 140.0.7339.16 (playwright build v1187) downloaded to /root/.cache/ms-playwright/chromium-1187
# Downloading Chromium Headless Shell 140.0.7339.16 (playwright build v1187) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1187/chromium-headless-shell-linux.zip
# 104.3 MiB [] 0% 0.0s104.3 MiB [] 0% 17.1s104.3 MiB [] 0% 15.6s104.3 MiB [] 0% 11.5s104.3 MiB [] 0% 7.6s104.3 MiB [] 1% 4.8s104.3 MiB [] 2% 3.2s104.3 MiB [] 4% 2.5s104.3 MiB [] 6% 2.0s104.3 MiB [] 7% 1.9s104.3 MiB [] 8% 1.7s104.3 MiB [] 9% 1.8s104.3 MiB [] 10% 1.7s104.3 MiB [] 12% 1.6s104.3 MiB [] 13% 1.5s104.3 MiB [] 15% 1.4s104.3 MiB [] 16% 1.4s104.3 MiB [] 18% 1.3s104.3 MiB [] 19% 1.3s104.3 MiB [] 21% 1.2s104.3 MiB [] 23% 1.1s104.3 MiB [] 25% 1.0s104.3 MiB [] 27% 1.0s104.3 MiB [] 29% 0.9s104.3 MiB [] 31% 0.9s104.3 MiB [] 33% 0.8s104.3 MiB [] 36% 0.8s104.3 MiB [] 38% 0.8s104.3 MiB [] 40% 0.7s104.3 MiB [] 43% 0.7s104.3 MiB [] 45% 0.6s104.3 MiB [] 48% 0.6s104.3 MiB [] 50% 0.6s104.3 MiB [] 51% 0.5s104.3 MiB [] 54% 0.5s104.3 MiB [] 56% 0.5s104.3 MiB [] 58% 0.5s104.3 MiB [] 59% 0.4s104.3 MiB [] 62% 0.4s104.3 MiB [] 65% 0.4s104.3 MiB [] 67% 0.3s104.3 MiB [] 70% 0.3s104.3 MiB [] 72% 0.3s104.3 MiB [] 75% 0.2s104.3 MiB [] 78% 0.2s104.3 MiB [] 81% 0.2s104.3 MiB [] 82% 0.2s104.3 MiB [] 84% 0.2s104.3 MiB [] 85% 0.1s104.3 MiB [] 87% 0.1s104.3 MiB [] 89% 0.1s104.3 MiB [] 90% 0.1s104.3 MiB [] 92% 0.1s104.3 MiB [] 93% 0.1s104.3 MiB [] 94% 0.1s104.3 MiB [] 95% 0.0s104.3 MiB [] 97% 0.0s104.3 MiB [] 99% 0.0s104.3 MiB [] 100% 0.0s
# Chromium Headless Shell 140.0.7339.16 (playwright build v1187) downloaded to /root/.cache/ms-playwright/chromium_headless_shell-1187
# Downloading Firefox 141.0 (playwright build v1490) from https://cdn.playwright.dev/dbazure/download/playwright/builds/firefox/1490/firefox-ubuntu-22.04.zip
# Error: socket hang up
#     at TLSSocket.socketOnEnd (node:_http_client:542:25)
#     at TLSSocket.emit (node:events:530:35)
#     at endReadableNT (node:internal/streams/readable:1698:12)
#     at process.processTicksAndRejections (node:internal/process/task_queues:90:21) {
#   code: 'ECONNRESET'
# }
# Downloading Firefox 141.0 (playwright build v1490) from https://playwright.download.prss.microsoft.com/dbazure/download/playwright/builds/firefox/1490/firefox-ubuntu-22.04.zip
# 96 MiB [] 0% 0.0s96 MiB [] 0% 19.8s96 MiB [] 0% 20.4s96 MiB [] 0% 13.8s96 MiB [] 0% 10.3s96 MiB [] 1% 6.8s96 MiB [] 2% 4.8s96 MiB [] 3% 3.5s96 MiB [] 4% 2.6s96 MiB [] 5% 2.4s96 MiB [] 6% 2.6s96 MiB [] 8% 2.2s96 MiB [] 8% 2.3s96 MiB [] 9% 2.2s96 MiB [] 10% 2.2s96 MiB [] 11% 2.1s96 MiB [] 12% 2.1s96 MiB [] 14% 1.8s96 MiB [] 15% 1.7s96 MiB [] 16% 1.6s96 MiB [] 18% 1.5s96 MiB [] 19% 1.5s96 MiB [] 21% 1.4s96 MiB [] 24% 1.3s96 MiB [] 26% 1.2s96 MiB [] 28% 1.1s96 MiB [] 29% 1.1s96 MiB [] 31% 1.0s96 MiB [] 33% 1.0s96 MiB [] 35% 0.9s96 MiB [] 37% 0.9s96 MiB [] 38% 0.9s96 MiB [] 39% 0.9s96 MiB [] 42% 0.8s96 MiB [] 43% 0.8s96 MiB [] 45% 0.8s96 MiB [] 47% 0.7s96 MiB [] 48% 0.7s96 MiB [] 50% 0.7s96 MiB [] 52% 0.7s96 MiB [] 54% 0.6s96 MiB [] 55% 0.6s96 MiB [] 56% 0.6s96 MiB [] 58% 0.6s96 MiB [] 60% 0.5s96 MiB [] 61% 0.5s96 MiB [] 62% 0.5s96 MiB [] 64% 0.5s96 MiB [] 66% 0.5s96 MiB [] 68% 0.5s96 MiB [] 70% 0.4s96 MiB [] 72% 0.4s96 MiB [] 75% 0.4s96 MiB [] 76% 0.4s96 MiB [] 77% 0.4s96 MiB [] 78% 0.3s96 MiB [] 79% 0.4s96 MiB [] 80% 0.3s96 MiB [] 81% 0.3s96 MiB [] 82% 0.3s96 MiB [] 83% 0.3s96 MiB [] 84% 0.3s96 MiB [] 86% 0.2s96 MiB [] 87% 0.2s96 MiB [] 89% 0.2s96 MiB [] 91% 0.1s96 MiB [] 92% 0.1s96 MiB [] 93% 0.1s96 MiB [] 95% 0.1s96 MiB [] 97% 0.0s96 MiB [] 98% 0.0s96 MiB [] 100% 0.0s
# Firefox 141.0 (playwright build v1490) downloaded to /root/.cache/ms-playwright/firefox-1490
# Downloading Webkit 26.0 (playwright build v2203) from https://cdn.playwright.dev/dbazure/download/playwright/builds/webkit/2203/webkit-ubuntu-22.04.zip
# 94.6 MiB [] 0% 0.0s94.6 MiB [] 0% 2.0s94.6 MiB [] 2% 1.2s94.6 MiB [] 4% 1.0s94.6 MiB [] 6% 0.9s94.6 MiB [] 8% 0.9s94.6 MiB [] 10% 0.9s94.6 MiB [] 11% 1.0s94.6 MiB [] 12% 1.0s94.6 MiB [] 14% 0.9s94.6 MiB [] 16% 0.9s94.6 MiB [] 17% 0.9s94.6 MiB [] 19% 0.9s94.6 MiB [] 21% 0.8s94.6 MiB [] 23% 0.8s94.6 MiB [] 25% 0.8s94.6 MiB [] 27% 0.7s94.6 MiB [] 29% 0.7s94.6 MiB [] 31% 0.7s94.6 MiB [] 34% 0.6s94.6 MiB [] 37% 0.6s94.6 MiB [] 38% 0.6s94.6 MiB [] 41% 0.5s94.6 MiB [] 43% 0.5s94.6 MiB [] 44% 0.5s94.6 MiB [] 46% 0.5s94.6 MiB [] 47% 0.5s94.6 MiB [] 48% 0.5s94.6 MiB [] 49% 0.5s94.6 MiB [] 50% 0.5s94.6 MiB [] 52% 0.5s94.6 MiB [] 54% 0.5s94.6 MiB [] 56% 0.4s94.6 MiB [] 58% 0.4s94.6 MiB [] 60% 0.4s94.6 MiB [] 63% 0.4s94.6 MiB [] 65% 0.3s94.6 MiB [] 68% 0.3s94.6 MiB [] 70% 0.3s94.6 MiB [] 72% 0.3s94.6 MiB [] 75% 0.2s94.6 MiB [] 77% 0.2s94.6 MiB [] 79% 0.2s94.6 MiB [] 81% 0.2s94.6 MiB [] 83% 0.1s94.6 MiB [] 86% 0.1s94.6 MiB [] 88% 0.1s94.6 MiB [] 91% 0.1s94.6 MiB [] 93% 0.1s94.6 MiB [] 96% 0.0s94.6 MiB [] 99% 0.0s94.6 MiB [] 100% 0.0s
# Webkit 26.0 (playwright build v2203) downloaded to /root/.cache/ms-playwright/webkit-2203
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# 2.3 MiB [] 0% 0.0s2.3 MiB [] 28% 0.0s2.3 MiB [] 71% 0.0s2.3 MiB [] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libavif.so.13                                    ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:934:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:1056:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/server/registry/index.js:1045:7)
#     at async i.<anonymous> (/usr/local/lib/python3.12/dist-packages/playwright/driver/package/lib/cli/program.js:217:7)

# %%
import asyncio
from playwright.async_api import async_playwright
import pandas as pd
import json
from datetime import datetime

async def scrape():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # List to store all product data for DataFrame
        all_products_data = []

        await page.goto("https://jalalsons.com.pk", timeout=60000)
        print("Navigated to site.")

        # --- FIRST ITERATION: Handle popup and select first branch ---
        try:
            if await page.locator("#website_custom_popup").is_visible():
                await page.locator('#website_custom_popup .modal-header a.cursor-pointer.ms-auto').click()
                print("✅ Popup closed.")
        except:
            print("⚠️ No popup found or already closed.")

        # Click delivery tab and get all branches
        await page.click("a#delivery-loc-tab")
        await page.wait_for_selector("#selectDeliveryBranch", timeout=10000)
        branches = await page.locator("#selectDeliveryBranch option").all_text_contents()
        valid_branches = [b for b in branches if "Please select" not in b and "Lahore" in b]

        print(f"\n📍 Found {len(valid_branches)} valid branches in Lahore")

        # --- Extract category structure once ---
        target_categories = ["BAKERY", "DELI", "JS ICECREAM", "SWEETS", "DEALS", "GROCERY"]

        # Process each branch
        for branch_index, branch_name in enumerate(valid_branches):
            print(f"\n{'='*80}")
            print(f"🏪 Processing Branch {branch_index }/{len(valid_branches)}: {branch_name}")
            print(f"{'='*80}")
            print(branch_index)


            if branch_index == 7:
                # First branch: already on the selection page
                print("sucessfully entered")
                await page.select_option("#selectDeliveryBranch", label=branch_name)
                await page.wait_for_timeout(2000)
                await page.click("a#delivery_order")
                print(f"✅ Selected first branch: {branch_name}")
            else:
                # Subsequent branches: click location header to reopen modal
                await page.click("a#get_current_loc")
                await page.wait_for_selector("#selectDeliveryBranch", timeout=10000)
                await page.wait_for_timeout(500)

                # Select the branch
                await page.select_option("#selectDeliveryBranch", label=branch_name)
                await page.wait_for_timeout(2000)
                await page.click("a#delivery_order")
                print(f"✅ Selected branch: {branch_name}")

            await page.wait_for_selector("ul.navbar-nav", timeout=10000)
            nav_items = await page.locator("ul.navbar-nav > li.nav-item").element_handles()

            # Extract category links for this branch
            category_links = {}
            for li in nav_items[:-3]:
                main_cat = await li.query_selector("a.nav-link")
                main_name = (await main_cat.inner_text()).strip()
                if main_name not in target_categories:
                    continue

                await main_cat.hover()
                await page.wait_for_timeout(500)
                sub_links = await li.query_selector_all("ul.dropdown-content a")

                urls = []
                if sub_links:
                    for sub in sub_links:
                        sub_name = (await sub.inner_text()).strip()
                        sub_href = await sub.get_attribute("href")
                        if sub_href:
                            urls.append({
                                "name": sub_name,
                                "url": f"https://jalalsons.com.pk{sub_href}"
                            })
                    category_links[main_name] = urls
                else:
                    href = await main_cat.get_attribute("href")
                    if href:
                        category_links[main_name] = [{
                            "name": main_name,
                            "url": f"https://jalalsons.com.pk{href}"
                        }]

            # --- Scrape products for each category ---
            for main_name, subcats in category_links.items():
                print(f"\n🔷 Category: {main_name}")

                for sub in subcats:
                    sub_name = sub["name"]
                    sub_url = sub["url"]
                    print(f"   🌐 Scraping {sub_name}: {sub_url}")

                    try:
                        await page.goto(sub_url, timeout=60000)
                        await page.wait_for_selector(".single_product_theme", timeout=10000)
                    except Exception as e:
                        print(f"   ⚠️ Could not load {sub_name}: {e}")
                        continue

                    products = await page.query_selector_all(".single_product_theme")

                    for product in products:
                        name_el = await product.query_selector("p.product_name_theme")
                        price_el = await product.query_selector("span.price-value")
                        img_el = await product.query_selector("img")

                        name = (await name_el.inner_text()).strip() if name_el else None
                        price = (await price_el.inner_text()).strip() if price_el else None
                        image = await img_el.get_attribute("src") if img_el else None

                        if name and price:
                            # Determine category and subcategory
                            if main_name == sub_name:
                                # No subcategory, main category only
                                category = main_name
                                subcategory = None
                            else:
                                # Has subcategory
                                category = main_name
                                subcategory = sub_name

                            all_products_data.append({
                                "branch": branch_name,
                                "category": category,
                                "subcategory": subcategory,
                                "product_name": name,
                                "price": price,
                                "image_url": image,
                                "product_url": sub_url
                            })

                    print(f"   ✅ Scraped {len(products)} products from {sub_name}")

        # --- Create DataFrame ---
        df = pd.DataFrame(all_products_data)

        # Reorder columns for better readability
        column_order = ["branch", "category", "subcategory", "product_name", "price", "image_url", "product_url"]
        df = df[column_order]

        # Save to CSV
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        csv_filename = f"jalalsons_products_{timestamp}.csv"
        df.to_csv(csv_filename, index=False, encoding='utf-8-sig')

        # Save to Excel for better formatting
        excel_filename = f"jalalsons_products_{timestamp}.xlsx"
        df.to_excel(excel_filename, index=False, sheet_name='Products')

        # Print summary statistics
        print(f"\n{'='*80}")
        print("📊 SCRAPING SUMMARY")
        print(f"{'='*80}")
        print(f"Total products scraped: {len(df)}")
        print(f"Total branches: {df['branch'].nunique()}")
        print(f"Total categories: {df['category'].nunique()}")
        print(f"\nProducts per branch:")
        print(df['branch'].value_counts())
        print(f"\nProducts per category:")
        print(df['category'].value_counts())
        print(f"\n✅ Data saved to:")
        print(f"   - {csv_filename}")
        print(f"   - {excel_filename}")

        # Display first few rows
        print(f"\n📋 Sample data:")
        print(df.head(10).to_string())

        await browser.close()

# Run
await scrape()
# Out:
# Navigated to site.
# ✅ Popup closed.
#
# 📍 Found 37 valid branches in Lahore
#
# ================================================================================
# 🏪 Processing Branch 7/37: Bahria Town ( Nishtar block ) Branch Lahore
# ================================================================================
# 7
# sucessfully entered
# ✅ Selected first branch: Bahria Town ( Nishtar block ) Branch Lahore
#
# 🔷 Category: BAKERY
#    🌐 Scraping Bread: https://jalalsons.com.pk/search?filter=10274
#    ✅ Scraped 13 products from Bread
#    🌐 Scraping Buns: https://jalalsons.com.pk/search?filter=10377
#    ✅ Scraped 10 products from Buns
#    🌐 Scraping Brownies: https://jalalsons.com.pk/search?filter=15568
#    ✅ Scraped 7 products from Brownies
#    🌐 Scraping Biscuits & Khatai: https://jalalsons.com.pk/search?filter=10466
#    ✅ Scraped 40 products from Biscuits & Khatai
#    🌐 Scraping Cakes: https://jalalsons.com.pk/search?filter=10379
#    ✅ Scraped 27 products from Cakes
#    🌐 Scraping Cake Rusk: https://jalalsons.com.pk/search?filter=14222
#    ✅ Scraped 8 products from Cake Rusk
#    🌐 Scraping Customise Cake: https://jalalsons.com.pk/customise-cake
#    ⚠️ Could not load Customise Cake: Page.wait_for_selector: Timeout 10000ms exceeded.
# Call log:
#   - waiting for locator(".single_product_theme") to be visible
#
#    🌐 Scraping Confectionery: https://jalalsons.com.pk/search?filter=14238
#    ✅ Scraped 4 products from Confectionery
#    🌐 Scraping Donuts & Cupcakes: https://jalalsons.com.pk/search?filter=23860
#    ✅ Scraped 20 products from Donuts & Cupcakes
#    🌐 Scraping Js Dairy: https://jalalsons.com.pk/search?filter=15865
#    ✅ Scraped 11 products from Js Dairy
#    🌐 Scraping Pastries: https://jalalsons.com.pk/search?filter=10465
#    ✅ Scraped 14 products from Pastries
#    🌐 Scraping Puff Pastries: https://jalalsons.com.pk/search?filter=10380
#    ✅ Scraped 13 products from Puff Pastries
#    🌐 Scraping Rusk: https://jalalsons.com.pk/search?filter=10277
#    ✅ Scraped 7 products from Rusk
#    🌐 Scraping Salted Snacks: https://jalalsons.com.pk/search?filter=10340
#    ✅ Scraped 11 products from Salted Snacks
#    🌐 Scraping Salad: https://jalalsons.com.pk/search?filter=23852
#    ✅ Scraped 1 products from Salad
#
# 🔷 Category: DELI
#    🌐 Scraping Burgers: https://jalalsons.com.pk/search?filter=10767
#    ✅ Scraped 7 products from Burgers
#    🌐 Scraping Crispy Fried Chicken: https://jalalsons.com.pk/search?filter=10771
#    ✅ Scraped 4 products from Crispy Fried Chicken
#    🌐 Scraping Deli Fish: https://jalalsons.com.pk/search?filter=10770
#    ✅ Scraped 3 products from Deli Fish
#    🌐 Scraping Italian Cuisine: https://jalalsons.com.pk/search?filter=18203
#    ✅ Scraped 3 products from Italian Cuisine
#    🌐 Scraping JS New Arrivals: https://jalalsons.com.pk/search?filter=10818
#    ✅ Scraped 16 products from JS New Arrivals
#    🌐 Scraping Pizza: https://jalalsons.com.pk/search?filter=10768
#    ✅ Scraped 11 products from Pizza
#    🌐 Scraping Per Peri Chicken: https://jalalsons.com.pk/search?filter=10769
#    ✅ Scraped 6 products from Per Peri Chicken
#    🌐 Scraping Sandwich: https://jalalsons.com.pk/search?filter=10294
#    ✅ Scraped 7 products from Sandwich
#
# 🔷 Category: JS ICECREAM
#    🌐 Scraping JS ICECREAM: https://jalalsons.com.pk/search?filter=13735
#    ✅ Scraped 17 products from JS ICECREAM
#
# 🔷 Category: SWEETS
#    🌐 Scraping SWEETS: https://jalalsons.com.pk/search?filter=10280
#    ✅ Scraped 33 products from SWEETS
#
# 🔷 Category: DEALS
#    🌐 Scraping DEALS: https://jalalsons.com.pk/search?filter=10799
#    ✅ Scraped 14 products from DEALS
#
# 🔷 Category: GROCERY
#    🌐 Scraping Butter: https://jalalsons.com.pk/search?filter=10322
#    ✅ Scraped 25 products from Butter
#    🌐 Scraping Baby Milk And Food: https://jalalsons.com.pk/search?filter=13721
#    ✅ Scraped 27 products from Baby Milk And Food
#    🌐 Scraping Beverages: https://jalalsons.com.pk/search?filter=13723
#    ✅ Scraped 134 products from Beverages
#    🌐 Scraping Biscuits , Crisps And Snacks: https://jalalsons.com.pk/search?filter=13752
#    ✅ Scraped 154 products from Biscuits , Crisps And Snacks
#    🌐 Scraping Baking Goods: https://jalalsons.com.pk/search?filter=13722
#    ✅ Scraped 15 products from Baking Goods
#    🌐 Scraping Canned Foods And Milks: https://jalalsons.com.pk/search?filter=13724
#    ✅ Scraped 38 products from Canned Foods And Milks
#    🌐 Scraping Cereal, Jams And Spreads: https://jalalsons.com.pk/search?filter=13725
#    ✅ Scraped 80 products from Cereal, Jams And Spreads
#    🌐 Scraping Confectionery And Chocolates: https://jalalsons.com.pk/search?filter=13727
#    ✅ Scraped 166 products from Confectionery And Chocolates
#    🌐 Scraping Cleaning Products: https://jalalsons.com.pk/search?filter=13726
#    ✅ Scraped 114 products from Cleaning Products
#    🌐 Scraping Cosmetics: https://jalalsons.com.pk/search?filter=13728
#    ✅ Scraped 18 products from Cosmetics
#    🌐 Scraping Diapers And Pampers: https://jalalsons.com.pk/search?filter=13729
#    ✅ Scraped 4 products from Diapers And Pampers
#    🌐 Scraping Dry Fruits And Dates: https://jalalsons.com.pk/search?filter=13730
#    ✅ Scraped 21 products from Dry Fruits And Dates
#    🌐 Scraping Fresh Milk And Eggs: https://jalalsons.com.pk/search?filter=13732
#    ✅ Scraped 53 products from Fresh Milk And Eggs
#    🌐 Scraping Frozen Foods: https://jalalsons.com.pk/search?filter=13733
#    ✅ Scraped 156 products from Frozen Foods
#    🌐 Scraping Flour, Rice And Pulses: https://jalalsons.com.pk/search?filter=13731
#    ✅ Scraped 44 products from Flour, Rice And Pulses
#    🌐 Scraping Ghee And Oil: https://jalalsons.com.pk/search?filter=13734
#    ✅ Scraped 57 products from Ghee And Oil
#    🌐 Scraping Ketchup, Sauce And Mayo: https://jalalsons.com.pk/search?filter=13736
#    ✅ Scraped 65 products from Ketchup, Sauce And Mayo
#    🌐 Scraping Mineral Water: https://jalalsons.com.pk/search?filter=13737
#    ✅ Scraped 18 products from Mineral Water
#    🌐 Scraping Other Food Items: https://jalalsons.com.pk/search?filter=13738
#    ✅ Scraped 43 products from Other Food Items
#    🌐 Scraping Personal Hygiene: https://jalalsons.com.pk/search?filter=13739
#    ✅ Scraped 18 products from Personal Hygiene
#    🌐 Scraping Pet Food: https://jalalsons.com.pk/search?filter=13740
#    ✅ Scraped 12 products from Pet Food
#    🌐 Scraping Powder Milk: https://jalalsons.com.pk/search?filter=13741
#    ✅ Scraped 12 products from Powder Milk
#    🌐 Scraping Spices And Miscellaneous: https://jalalsons.com.pk/search?filter=13742
#    ✅ Scraped 81 products from Spices And Miscellaneous
#    🌐 Scraping Tea And Coffee: https://jalalsons.com.pk/search?filter=13743
#    ✅ Scraped 57 products from Tea And Coffee
#    🌐 Scraping Toiletries: https://jalalsons.com.pk/search?filter=13745
#    ✅ Scraped 167 products from Toiletries
#    🌐 Scraping Tissues And Sanitary: https://jalalsons.com.pk/search?filter=13744
#    ✅ Scraped 45 products from Tissues And Sanitary
#    🌐 Scraping Yoghurt, Butter, Cream And Cheese: https://jalalsons.com.pk/search?filter=13746
#    ✅ Scraped 74 products from Yoghurt, Butter, Cream And Cheese
#
# ================================================================================
# 🏪 Processing Branch 8/37: Cantt CSD Branch  Lahore
# ================================================================================
# 8
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /tmp/ipython-input-166666511.py in <cell line: 1>()
#     184
#     185 # Run
# --> 186 await scrape()
#
# /tmp/ipython-input-166666511.py in scrape()
#      57
#      58                 # Select the branch
# ---> 59                 await page.select_option("#selectDeliveryBranch", label=branch_name)
#      60                 await page.wait_for_timeout(2000)
#      61                 await page.click("a#delivery_order")
#
# /usr/local/lib/python3.12/dist-packages/playwright/async_api/_generated.py in select_option(self, selector, value, index, label, element, timeout, no_wait_after, force, strict)
#   11030
#   11031         return mapping.from_maybe_impl(
# > 11032             await self._impl_obj.select_option(
#   11033                 selector=selector,
#   11034                 value=mapping.to_impl(value),
#
# /usr/local/lib/python3.12/dist-packages/playwright/_impl/_page.py in select_option(self, selector, value, index, label, element, timeout, noWaitAfter, force, strict)
#    1035     ) -> List[str]:
#    1036         params = locals_to_params(locals())
# -> 1037         return await self._main_frame.select_option(**params)
#    1038
#    1039     async def input_value(
#
# /usr/local/lib/python3.12/dist-packages/playwright/_impl/_frame.py in select_option(self, selector, value, index, label, element, timeout, noWaitAfter, strict, force)
#     761             )
#     762         )
# --> 763         return await self._channel.send("selectOption", self._timeout, params)
#     764
#     765     async def input_value(
#
# /usr/local/lib/python3.12/dist-packages/playwright/_impl/_connection.py in send(self, method, timeout_calculator, params, is_internal, title)
#      67         title: str = None,
#      68     ) -> Any:
# ---> 69         return await self._connection.wrap_api_call(
#      70             lambda: self._inner_send(method, timeout_calculator, params, False),
#      71             is_internal,
#
# /usr/local/lib/python3.12/dist-packages/playwright/_impl/_connection.py in wrap_api_call(self, cb, is_internal, title)
#     556             return await cb()
#     557         except Exception as error:
# --> 558             raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     559         finally:
#     560             self._api_zone.set(None)
#
# TimeoutError: Page.select_option: Timeout 30000ms exceeded.
# Call log:
#   - waiting for locator("#selectDeliveryBranch")
#     - locator resolved to <select id="selectDeliveryBranch" class="form-select py-0 px-3 shadow-none focus branches_result">…</select>
#   - attempting select option action
#     2 × waiting for element to be visible and enabled
#       - did not find some options
#     - retrying select option action
#     - waiting 20ms
#     2 × waiting for element to be visible and enabled
#       - did not find some options
#     - retrying select option action
#       - waiting 100ms
#     59 × waiting for element to be visible and enabled
#        - did not find some options
#      - retrying select option action
#        - waiting 500ms

# %%
import asyncio
from playwright.async_api import async_playwright
import pandas as pd
from datetime import datetime

# ==================== CONFIGURATION ====================
BRANCH_START = 0   # inclusive (0 = first branch)
BRANCH_END = 7    # exclusive (10 = scrape first 10 branches)
# Example for next run: BRANCH_START = 10, BRANCH_END = 20
# =======================================================

async def scrape():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        all_products_data = []

        await page.goto("https://jalalsons.com.pk", timeout=60000)
        print("Navigated to site.")

        # --- Handle popup ---
        try:
            if await page.locator("#website_custom_popup").is_visible():
                await page.locator('#website_custom_popup .modal-header a.cursor-pointer.ms-auto').click()
                print("✅ Popup closed.")
        except:
            print("⚠️ No popup found or already closed.")

        # Click delivery tab and get all branches
        await page.click("a#delivery-loc-tab")
        await page.wait_for_selector("#selectDeliveryBranch", timeout=10000)
        branches = await page.locator("#selectDeliveryBranch option").all_text_contents()
        valid_branches = [b for b in branches if "Please select" not in b and "Lahore" in b]

        total_branches = len(valid_branches)
        print(f"\n📍 Found {total_branches} valid branches in Lahore")

        # Ensure range is valid
        if BRANCH_START >= total_branches:
            print(f"❌ BRANCH_START={BRANCH_START} is beyond total branches ({total_branches}).")
            await browser.close()
            return
        if BRANCH_END > total_branches:
            BRANCH_END = total_branches

        branches_to_process = valid_branches[BRANCH_START:BRANCH_END]
        print(f"🎯 Scraping branches {BRANCH_START} to {BRANCH_END-1}")
        print(f"📋 Branches: {branches_to_process}")

        target_categories = ["BAKERY", "DELI", "JS ICECREAM", "SWEETS", "DEALS", "GROCERY"]

        # --- Process each branch in range ---
        for branch_index, branch_name in enumerate(branches_to_process, start=BRANCH_START + 1):
            print(f"\n{'='*80}")
            print(f"🏪 Processing Branch #{branch_index}: {branch_name}")
            print(f"{'='*80}")

            if branch_index == BRANCH_START + 1:
                await page.select_option("#selectDeliveryBranch", label=branch_name)
                await page.wait_for_timeout(2000)
                await page.click("a#delivery_order")
                print(f"✅ Selected first branch: {branch_name}")
            else:
                await page.click("a#get_current_loc")
                await page.wait_for_selector("#selectDeliveryBranch", timeout=10000)
                await page.wait_for_timeout(500)
                await page.select_option("#selectDeliveryBranch", label=branch_name)
                await page.wait_for_timeout(2000)
                await page.click("a#delivery_order")
                print(f"✅ Selected branch: {branch_name}")

            await page.wait_for_selector("ul.navbar-nav", timeout=10000)
            nav_items = await page.locator("ul.navbar-nav > li.nav-item").element_handles()

            category_links = {}
            for li in nav_items[:-3]:
                main_cat = await li.query_selector("a.nav-link")
                main_name = (await main_cat.inner_text()).strip()
                if main_name not in target_categories:
                    continue

                await main_cat.hover()
                await page.wait_for_timeout(500)
                sub_links = await li.query_selector_all("ul.dropdown-content a")

                urls = []
                if sub_links:
                    for sub in sub_links:
                        sub_name = (await sub.inner_text()).strip()
                        sub_href = await sub.get_attribute("href")
                        if sub_href:
                            urls.append({
                                "name": sub_name,
                                "url": f"https://jalalsons.com.pk{sub_href}"
                            })
                    category_links[main_name] = urls
                else:
                    href = await main_cat.get_attribute("href")
                    if href:
                        category_links[main_name] = [{
                            "name": main_name,
                            "url": f"https://jalalsons.com.pk{href}"
                        }]

            # --- Scrape products ---
            for main_name, subcats in category_links.items():
                print(f"\n🔷 Category: {main_name}")

                for sub in subcats:
                    sub_name = sub["name"]
                    sub_url = sub["url"]
                    print(f"   🌐 Scraping {sub_name}: {sub_url}")

                    try:
                        await page.goto(sub_url, timeout=60000)
                        await page.wait_for_selector(".single_product_theme", timeout=10000)
                    except Exception as e:
                        print(f"   ⚠️ Could not load {sub_name}: {e}")
                        continue

                    products = await page.query_selector_all(".single_product_theme")

                    for product in products:
                        name_el = await product.query_selector("p.product_name_theme")
                        price_el = await product.query_selector("span.price-value")
                        img_el = await product.query_selector("img")

                        name = (await name_el.inner_text()).strip() if name_el else None
                        price = (await price_el.inner_text()).strip() if price_el else None
                        image = await img_el.get_attribute("src") if img_el else None

                        if name and price:
                            category = main_name
                            subcategory = None if main_name == sub_name else sub_name

                            all_products_data.append({
                                "branch": branch_name,
                                "category": category,
                                "subcategory": subcategory,
                                "product_name": name,
                                "price": price,
                                "image_url": image,
                                "product_url": sub_url
                            })

                    print(f"   ✅ Scraped {len(products)} products from {sub_name}")

        # --- Save Results ---
        df = pd.DataFrame(all_products_data)
        if df.empty:
            print("⚠️ No products scraped.")
            await browser.close()
            return

        column_order = ["branch", "category", "subcategory", "product_name", "price", "image_url", "product_url"]
        df = df[column_order]

        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        csv_filename = f"jalalsons_products_part_{BRANCH_START+1}_{BRANCH_END}_{timestamp}.csv"
        df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
        print(f"\n✅ Data saved to: {csv_filename}")

        print(f"\n📊 Summary:")
        print(f"Total products: {len(df)}")
        print(f"Branches scraped: {df['branch'].nunique()}")
        print(df['branch'].value_counts())
        print(f"\nSample:\n{df.head(10)}")

        await browser.close()

# Run
await scrape()
# Out:
# Navigated to site.
# ✅ Popup closed.
#
# 📍 Found 37 valid branches in Lahore
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-822244187.py in <cell line: 1>()
#     171
#     172 # Run
# --> 173 await scrape()
#
# /tmp/ipython-input-822244187.py in scrape()
#      42             await browser.close()
#      43             return
# ---> 44         if BRANCH_END > total_branches:
#      45             BRANCH_END = total_branches
#      46
#
# UnboundLocalError: cannot access local variable 'BRANCH_END' where it is not associated with a value
